# %%
import biotite.structure as struc
import biotite.structure.io as strucio
from biotite.structure.io.pdb import PDBFile
import numpy as np
from collections import defaultdict

atom_array = strucio.load_structure(file_path='3U8K.pdb', model=1, altloc='first')
one_complex = atom_array[np.isin(atom_array.chain_id, ['A', 'B', 'C', 'D', 'E'])]
one_complex_protein_only = one_complex[struc.filter_amino_acids(one_complex)]
print(len(one_complex_protein_only))
# Out:
# 8122

# %%
"""
This script iterates over adjacent chain pairs (A-B, B-C, C-D, D-E, E-A), computes all inter-chain atom-atom distances, 
and identifies interface residues by selecting residue pairs with any heavy-atom contacts closer than 4 Å.
For each chain pair, it aggregates these contacts at the residue level and prints a residue-to-residue interaction map, 
which can be compared across pairs to assess whether the interfaces are identical and thus whether the complex is perfectly symmetric.
"""

chain_list_1 = ['A', 'B', 'C', 'D', 'E']
chain_list_2 = ['B', 'C', 'D', 'E', 'A']

chain_combine = list(zip(chain_list_1, chain_list_2))
print(chain_combine)

dist_pair_together = []
for combi in chain_combine:
    chain_1, chain_2 = combi
    two_chains = one_complex_protein_only[np.isin(one_complex_protein_only.chain_id, [chain_1, chain_2])]
    print(f"Shape of {chain_1} and {chain_2}: {two_chains.shape}")
    
    # check if there is any hydrogens
    # if the shape of only heavy atom is the same with before, that means no hydrogen
    two_chains_heavy = two_chains[np.isin(two_chains.element, ['C', 'N', 'O', 'S'])]
    print(f"Shape of {chain_1} and {chain_2}: {two_chains_heavy.shape}")
    
    # build distance matrix between two adjacent chains
    chain_1 = one_complex_protein_only[one_complex_protein_only.chain_id == chain_1]
    chain_2 = one_complex_protein_only[one_complex_protein_only.chain_id == chain_2]
    chain_1_coord = chain_1.coord
    chain_2_coord = chain_2.coord
    diff = chain_1_coord[None,:,:] - chain_2_coord[:,None,:]
    dist = np.linalg.norm(diff, axis=-1)
    I, J = np.where(dist < 4) # I, J are array index
    
    # Extract the resn and resi
    # print(f"chain_1.res_id: {chain_1.res_id}")
    chain_1_resid_list = [(chain_1.res_id[j], chain_1.res_name[j]) for j in J]
    chain_2_resid_list = [(chain_2.res_id[i], chain_2.res_name[i]) for i in I]
    interaction_pair = set(list(zip(chain_1_resid_list, chain_2_resid_list)))
    print(f"interaction_pair: {interaction_pair}")
    
    # collectly build up interaction
    grouped = defaultdict(set)
    for res1, res2 in interaction_pair:
        grouped[res1].add(res2)
        
    for res1, partners in sorted(grouped.items()):
        partners_str = ", ".join(
            f"{res2[1]}{res2[0]}" for res2 in sorted(partners)
        )
        print(f"{res1[1]}{res1[0]} -> {partners_str}")
# Out:
# [('A', 'B'), ('B', 'C'), ('C', 'D'), ('D', 'E'), ('E', 'A')]
# Shape of A and B: (3268,)
# Shape of A and B: (3268,)
# interaction_pair: {((np.int64(92), np.str_('ILE')), (np.int64(118), np.str_('ARG'))), ((np.int64(187), np.str_('CYS')), (np.int64(55), np.str_('GLN'))), ((np.int64(87), np.str_('ALA')), (np.int64(100), np.str_('PRO'))), ((np.int64(15), np.str_('ARG')), (np.int64(7), np.str_('LEU'))), ((np.int64(94), np.str_('LYS')), (np.int64(98), np.str_('LEU'))), ((np.int64(85), np.str_('ASP')), (np.int64(102), np.str_('LEU'))), ((np.int64(93), np.str_('SER')), (np.int64(96), np.str_('GLU'))), ((np.int64(144), np.str_('THR')), (np.int64(75), np.str_('SER'))), ((np.int64(91), np.str_('ALA')), (np.int64(98), np.str_('LEU'))), ((np.int64(15), np.str_('ARG')), (np.int64(4), np.str_('ALA'))), ((np.int64(146), np.str_('HIS')), (np.int64(104), np.str_('ARG'))), ((np.int64(44), np.str_('ILE')), (np.int64(170), np.str_('ARG'))), ((np.int64(122), np.str_('SER')), (np.int64(166), np.str_('SER'))), ((np.int64(47), np.str_('GLU')), (np.int64(39), np.str_('LEU'))), ((np.int64(94), np.str_('LYS')), (np.int64(96), np.str_('GLU'))), ((np.int64(186), np.str_('SER')), (np.int64(163), np.str_('GLU'))), ((np.int64(46), np.str_('ASN')), (np.int64(168), np.str_('TYR'))), ((np.int64(145), np.str_('HIS')), (np.int64(75), np.str_('SER'))), ((np.int64(185), np.str_('TYR')), (np.int64(164), np.str_('TYR'))), ((np.int64(124), np.str_('ASP')), (np.int64(168), np.str_('TYR'))), ((np.int64(123), np.str_('CYS')), (np.int64(168), np.str_('TYR'))), ((np.int64(149), np.str_('GLU')), (np.int64(3), np.str_('ARG'))), ((np.int64(122), np.str_('SER')), (np.int64(37), np.str_('ASN'))), ((np.int64(19), np.str_('ILE')), (np.int64(3), np.str_('ARG'))), ((np.int64(21), np.str_('THR')), (np.int64(3), np.str_('ARG'))), ((np.int64(144), np.str_('THR')), (np.int64(104), np.str_('ARG'))), ((np.int64(17), np.str_('ASP')), (np.int64(7), np.str_('LEU'))), ((np.int64(94), np.str_('LYS')), (np.int64(97), np.str_('VAL'))), ((np.int64(149), np.str_('GLU')), (np.int64(104), np.str_('ARG'))), ((np.int64(186), np.str_('SER')), (np.int64(164), np.str_('TYR'))), ((np.int64(86), np.str_('LEU')), (np.int64(100), np.str_('PRO'))), ((np.int64(143), np.str_('TRP')), (np.int64(53), np.str_('TRP'))), ((np.int64(187), np.str_('CYS')), (np.int64(164), np.str_('TYR'))), ((np.int64(143), np.str_('TRP')), (np.int64(116), np.str_('SER'))), ((np.int64(93), np.str_('SER')), (np.int64(98), np.str_('LEU'))), ((np.int64(85), np.str_('ASP')), (np.int64(100), np.str_('PRO'))), ((np.int64(18), np.str_('VAL')), (np.int64(4), np.str_('ALA'))), ((np.int64(187), np.str_('CYS')), (np.int64(114), np.str_('MET'))), ((np.int64(137), np.str_('ARG')), (np.int64(168), np.str_('TYR'))), ((np.int64(145), np.str_('HIS')), (np.int64(104), np.str_('ARG'))), ((np.int64(15), np.str_('ARG')), (np.int64(8), np.str_('TYR'))), ((np.int64(143), np.str_('TRP')), (np.int64(114), np.str_('MET'))), ((np.int64(144), np.str_('THR')), (np.int64(102), np.str_('LEU'))), ((np.int64(143), np.str_('TRP')), (np.int64(99), np.str_('THR'))), ((np.int64(24), np.str_('ASP')), (np.int64(3), np.str_('ARG')))}
# ARG15 -> ALA4, LEU7, TYR8
# ASP17 -> LEU7
# VAL18 -> ALA4
# ILE19 -> ARG3
# THR21 -> ARG3
# ASP24 -> ARG3
# ILE44 -> ARG170
# ASN46 -> TYR168
# GLU47 -> LEU39
# ASP85 -> PRO100, LEU102
# LEU86 -> PRO100
# ALA87 -> PRO100
# ALA91 -> LEU98
# ILE92 -> ARG118
# SER93 -> GLU96, LEU98
# LYS94 -> GLU96, VAL97, LEU98
# SER122 -> ASN37, SER166
# CYS123 -> TYR168
# ASP124 -> TYR168
# ARG137 -> TYR168
# TRP143 -> TRP53, THR99, MET114, SER116
# THR144 -> SER75, LEU102, ARG104
# HIS145 -> SER75, ARG104
# HIS146 -> ARG104
# GLU149 -> ARG3, ARG104
# TYR185 -> TYR164
# SER186 -> GLU163, TYR164
# CYS187 -> GLN55, MET114, TYR164
# Shape of B and C: (3220,)
# Shape of B and C: (3220,)
# interaction_pair: {((np.int64(92), np.str_('ILE')), (np.int64(118), np.str_('ARG'))), ((np.int64(187), np.str_('CYS')), (np.int64(55), np.str_('GLN'))), ((np.int64(87), np.str_('ALA')), (np.int64(100), np.str_('PRO'))), ((np.int64(15), np.str_('ARG')), (np.int64(7), np.str_('LEU'))), ((np.int64(94), np.str_('LYS')), (np.int64(98), np.str_('LEU'))), ((np.int64(85), np.str_('ASP')), (np.int64(102), np.str_('LEU'))), ((np.int64(93), np.str_('SER')), (np.int64(96), np.str_('GLU'))), ((np.int64(144), np.str_('THR')), (np.int64(75), np.str_('SER'))), ((np.int64(91), np.str_('ALA')), (np.int64(98), np.str_('LEU'))), ((np.int64(15), np.str_('ARG')), (np.int64(4), np.str_('ALA'))), ((np.int64(146), np.str_('HIS')), (np.int64(104), np.str_('ARG'))), ((np.int64(44), np.str_('ILE')), (np.int64(170), np.str_('ARG'))), ((np.int64(122), np.str_('SER')), (np.int64(166), np.str_('SER'))), ((np.int64(47), np.str_('GLU')), (np.int64(39), np.str_('LEU'))), ((np.int64(186), np.str_('SER')), (np.int64(157), np.str_('GLU'))), ((np.int64(94), np.str_('LYS')), (np.int64(96), np.str_('GLU'))), ((np.int64(186), np.str_('SER')), (np.int64(163), np.str_('GLU'))), ((np.int64(46), np.str_('ASN')), (np.int64(168), np.str_('TYR'))), ((np.int64(145), np.str_('HIS')), (np.int64(75), np.str_('SER'))), ((np.int64(185), np.str_('TYR')), (np.int64(164), np.str_('TYR'))), ((np.int64(124), np.str_('ASP')), (np.int64(168), np.str_('TYR'))), ((np.int64(123), np.str_('CYS')), (np.int64(168), np.str_('TYR'))), ((np.int64(122), np.str_('SER')), (np.int64(37), np.str_('ASN'))), ((np.int64(149), np.str_('GLU')), (np.int64(3), np.str_('ARG'))), ((np.int64(19), np.str_('ILE')), (np.int64(3), np.str_('ARG'))), ((np.int64(21), np.str_('THR')), (np.int64(3), np.str_('ARG'))), ((np.int64(144), np.str_('THR')), (np.int64(104), np.str_('ARG'))), ((np.int64(17), np.str_('ASP')), (np.int64(7), np.str_('LEU'))), ((np.int64(94), np.str_('LYS')), (np.int64(97), np.str_('VAL'))), ((np.int64(149), np.str_('GLU')), (np.int64(104), np.str_('ARG'))), ((np.int64(186), np.str_('SER')), (np.int64(164), np.str_('TYR'))), ((np.int64(86), np.str_('LEU')), (np.int64(100), np.str_('PRO'))), ((np.int64(143), np.str_('TRP')), (np.int64(53), np.str_('TRP'))), ((np.int64(18), np.str_('VAL')), (np.int64(7), np.str_('LEU'))), ((np.int64(187), np.str_('CYS')), (np.int64(164), np.str_('TYR'))), ((np.int64(87), np.str_('ALA')), (np.int64(99), np.str_('THR'))), ((np.int64(93), np.str_('SER')), (np.int64(98), np.str_('LEU'))), ((np.int64(85), np.str_('ASP')), (np.int64(100), np.str_('PRO'))), ((np.int64(18), np.str_('VAL')), (np.int64(4), np.str_('ALA'))), ((np.int64(187), np.str_('CYS')), (np.int64(114), np.str_('MET'))), ((np.int64(137), np.str_('ARG')), (np.int64(168), np.str_('TYR'))), ((np.int64(145), np.str_('HIS')), (np.int64(104), np.str_('ARG'))), ((np.int64(15), np.str_('ARG')), (np.int64(8), np.str_('TYR'))), ((np.int64(143), np.str_('TRP')), (np.int64(114), np.str_('MET'))), ((np.int64(144), np.str_('THR')), (np.int64(102), np.str_('LEU'))), ((np.int64(143), np.str_('TRP')), (np.int64(99), np.str_('THR')))}
# ARG15 -> ALA4, LEU7, TYR8
# ASP17 -> LEU7
# VAL18 -> ALA4, LEU7
# ILE19 -> ARG3
# THR21 -> ARG3
# ILE44 -> ARG170
# ASN46 -> TYR168
# GLU47 -> LEU39
# ASP85 -> PRO100, LEU102
# LEU86 -> PRO100
# ALA87 -> THR99, PRO100
# ALA91 -> LEU98
# ILE92 -> ARG118
# SER93 -> GLU96, LEU98
# LYS94 -> GLU96, VAL97, LEU98
# SER122 -> ASN37, SER166
# CYS123 -> TYR168
# ASP124 -> TYR168
# ARG137 -> TYR168
# TRP143 -> TRP53, THR99, MET114
# THR144 -> SER75, LEU102, ARG104
# HIS145 -> SER75, ARG104
# HIS146 -> ARG104
# GLU149 -> ARG3, ARG104
# TYR185 -> TYR164
# SER186 -> GLU157, GLU163, TYR164
# CYS187 -> GLN55, MET114, TYR164
# Shape of C and D: (3246,)
# Shape of C and D: (3246,)
# interaction_pair: {((np.int64(92), np.str_('ILE')), (np.int64(118), np.str_('ARG'))), ((np.int64(187), np.str_('CYS')), (np.int64(55), np.str_('GLN'))), ((np.int64(87), np.str_('ALA')), (np.int64(100), np.str_('PRO'))), ((np.int64(15), np.str_('ARG')), (np.int64(7), np.str_('LEU'))), ((np.int64(94), np.str_('LYS')), (np.int64(98), np.str_('LEU'))), ((np.int64(85), np.str_('ASP')), (np.int64(102), np.str_('LEU'))), ((np.int64(93), np.str_('SER')), (np.int64(96), np.str_('GLU'))), ((np.int64(144), np.str_('THR')), (np.int64(75), np.str_('SER'))), ((np.int64(91), np.str_('ALA')), (np.int64(98), np.str_('LEU'))), ((np.int64(15), np.str_('ARG')), (np.int64(4), np.str_('ALA'))), ((np.int64(146), np.str_('HIS')), (np.int64(104), np.str_('ARG'))), ((np.int64(44), np.str_('ILE')), (np.int64(170), np.str_('ARG'))), ((np.int64(122), np.str_('SER')), (np.int64(166), np.str_('SER'))), ((np.int64(47), np.str_('GLU')), (np.int64(39), np.str_('LEU'))), ((np.int64(94), np.str_('LYS')), (np.int64(96), np.str_('GLU'))), ((np.int64(186), np.str_('SER')), (np.int64(163), np.str_('GLU'))), ((np.int64(46), np.str_('ASN')), (np.int64(168), np.str_('TYR'))), ((np.int64(145), np.str_('HIS')), (np.int64(75), np.str_('SER'))), ((np.int64(185), np.str_('TYR')), (np.int64(164), np.str_('TYR'))), ((np.int64(124), np.str_('ASP')), (np.int64(168), np.str_('TYR'))), ((np.int64(123), np.str_('CYS')), (np.int64(168), np.str_('TYR'))), ((np.int64(122), np.str_('SER')), (np.int64(37), np.str_('ASN'))), ((np.int64(149), np.str_('GLU')), (np.int64(3), np.str_('ARG'))), ((np.int64(19), np.str_('ILE')), (np.int64(3), np.str_('ARG'))), ((np.int64(21), np.str_('THR')), (np.int64(3), np.str_('ARG'))), ((np.int64(144), np.str_('THR')), (np.int64(104), np.str_('ARG'))), ((np.int64(17), np.str_('ASP')), (np.int64(7), np.str_('LEU'))), ((np.int64(94), np.str_('LYS')), (np.int64(97), np.str_('VAL'))), ((np.int64(149), np.str_('GLU')), (np.int64(104), np.str_('ARG'))), ((np.int64(186), np.str_('SER')), (np.int64(164), np.str_('TYR'))), ((np.int64(86), np.str_('LEU')), (np.int64(100), np.str_('PRO'))), ((np.int64(143), np.str_('TRP')), (np.int64(53), np.str_('TRP'))), ((np.int64(18), np.str_('VAL')), (np.int64(7), np.str_('LEU'))), ((np.int64(187), np.str_('CYS')), (np.int64(164), np.str_('TYR'))), ((np.int64(143), np.str_('TRP')), (np.int64(116), np.str_('SER'))), ((np.int64(93), np.str_('SER')), (np.int64(98), np.str_('LEU'))), ((np.int64(85), np.str_('ASP')), (np.int64(100), np.str_('PRO'))), ((np.int64(18), np.str_('VAL')), (np.int64(4), np.str_('ALA'))), ((np.int64(187), np.str_('CYS')), (np.int64(114), np.str_('MET'))), ((np.int64(137), np.str_('ARG')), (np.int64(168), np.str_('TYR'))), ((np.int64(145), np.str_('HIS')), (np.int64(104), np.str_('ARG'))), ((np.int64(15), np.str_('ARG')), (np.int64(8), np.str_('TYR'))), ((np.int64(143), np.str_('TRP')), (np.int64(114), np.str_('MET'))), ((np.int64(144), np.str_('THR')), (np.int64(102), np.str_('LEU'))), ((np.int64(143), np.str_('TRP')), (np.int64(99), np.str_('THR')))}
# ARG15 -> ALA4, LEU7, TYR8
# ASP17 -> LEU7
# VAL18 -> ALA4, LEU7
# ILE19 -> ARG3
# THR21 -> ARG3
# ILE44 -> ARG170
# ASN46 -> TYR168
# GLU47 -> LEU39
# ASP85 -> PRO100, LEU102
# LEU86 -> PRO100
# ALA87 -> PRO100
# ALA91 -> LEU98
# ILE92 -> ARG118
# SER93 -> GLU96, LEU98
# LYS94 -> GLU96, VAL97, LEU98
# SER122 -> ASN37, SER166
# CYS123 -> TYR168
# ASP124 -> TYR168
# ARG137 -> TYR168
# TRP143 -> TRP53, THR99, MET114, SER116
# THR144 -> SER75, LEU102, ARG104
# HIS145 -> SER75, ARG104
# HIS146 -> ARG104
# GLU149 -> ARG3, ARG104
# TYR185 -> TYR164
# SER186 -> GLU163, TYR164
# CYS187 -> GLN55, MET114, TYR164
# Shape of D and E: (3232,)
# Shape of D and E: (3232,)
# interaction_pair: {((np.int64(92), np.str_('ILE')), (np.int64(118), np.str_('ARG'))), ((np.int64(187), np.str_('CYS')), (np.int64(55), np.str_('GLN'))), ((np.int64(87), np.str_('ALA')), (np.int64(100), np.str_('PRO'))), ((np.int64(15), np.str_('ARG')), (np.int64(7), np.str_('LEU'))), ((np.int64(94), np.str_('LYS')), (np.int64(98), np.str_('LEU'))), ((np.int64(85), np.str_('ASP')), (np.int64(102), np.str_('LEU'))), ((np.int64(93), np.str_('SER')), (np.int64(96), np.str_('GLU'))), ((np.int64(45), np.str_('THR')), (np.int64(168), np.str_('TYR'))), ((np.int64(92), np.str_('ILE')), (np.int64(39), np.str_('LEU'))), ((np.int64(144), np.str_('THR')), (np.int64(75), np.str_('SER'))), ((np.int64(91), np.str_('ALA')), (np.int64(98), np.str_('LEU'))), ((np.int64(15), np.str_('ARG')), (np.int64(4), np.str_('ALA'))), ((np.int64(146), np.str_('HIS')), (np.int64(104), np.str_('ARG'))), ((np.int64(44), np.str_('ILE')), (np.int64(170), np.str_('ARG'))), ((np.int64(122), np.str_('SER')), (np.int64(166), np.str_('SER'))), ((np.int64(47), np.str_('GLU')), (np.int64(39), np.str_('LEU'))), ((np.int64(94), np.str_('LYS')), (np.int64(96), np.str_('GLU'))), ((np.int64(186), np.str_('SER')), (np.int64(163), np.str_('GLU'))), ((np.int64(46), np.str_('ASN')), (np.int64(168), np.str_('TYR'))), ((np.int64(145), np.str_('HIS')), (np.int64(75), np.str_('SER'))), ((np.int64(185), np.str_('TYR')), (np.int64(164), np.str_('TYR'))), ((np.int64(124), np.str_('ASP')), (np.int64(168), np.str_('TYR'))), ((np.int64(123), np.str_('CYS')), (np.int64(168), np.str_('TYR'))), ((np.int64(122), np.str_('SER')), (np.int64(37), np.str_('ASN'))), ((np.int64(149), np.str_('GLU')), (np.int64(3), np.str_('ARG'))), ((np.int64(19), np.str_('ILE')), (np.int64(3), np.str_('ARG'))), ((np.int64(21), np.str_('THR')), (np.int64(3), np.str_('ARG'))), ((np.int64(144), np.str_('THR')), (np.int64(104), np.str_('ARG'))), ((np.int64(17), np.str_('ASP')), (np.int64(7), np.str_('LEU'))), ((np.int64(94), np.str_('LYS')), (np.int64(97), np.str_('VAL'))), ((np.int64(149), np.str_('GLU')), (np.int64(104), np.str_('ARG'))), ((np.int64(186), np.str_('SER')), (np.int64(164), np.str_('TYR'))), ((np.int64(86), np.str_('LEU')), (np.int64(100), np.str_('PRO'))), ((np.int64(143), np.str_('TRP')), (np.int64(53), np.str_('TRP'))), ((np.int64(18), np.str_('VAL')), (np.int64(7), np.str_('LEU'))), ((np.int64(187), np.str_('CYS')), (np.int64(164), np.str_('TYR'))), ((np.int64(87), np.str_('ALA')), (np.int64(99), np.str_('THR'))), ((np.int64(93), np.str_('SER')), (np.int64(98), np.str_('LEU'))), ((np.int64(85), np.str_('ASP')), (np.int64(100), np.str_('PRO'))), ((np.int64(18), np.str_('VAL')), (np.int64(4), np.str_('ALA'))), ((np.int64(187), np.str_('CYS')), (np.int64(114), np.str_('MET'))), ((np.int64(137), np.str_('ARG')), (np.int64(168), np.str_('TYR'))), ((np.int64(145), np.str_('HIS')), (np.int64(104), np.str_('ARG'))), ((np.int64(15), np.str_('ARG')), (np.int64(8), np.str_('TYR'))), ((np.int64(143), np.str_('TRP')), (np.int64(114), np.str_('MET'))), ((np.int64(144), np.str_('THR')), (np.int64(102), np.str_('LEU'))), ((np.int64(143), np.str_('TRP')), (np.int64(99), np.str_('THR'))), ((np.int64(24), np.str_('ASP')), (np.int64(3), np.str_('ARG')))}
# ARG15 -> ALA4, LEU7, TYR8
# ASP17 -> LEU7
# VAL18 -> ALA4, LEU7
# ILE19 -> ARG3
# THR21 -> ARG3
# ASP24 -> ARG3
# ILE44 -> ARG170
# THR45 -> TYR168
# ASN46 -> TYR168
# GLU47 -> LEU39
# ASP85 -> PRO100, LEU102
# LEU86 -> PRO100
# ALA87 -> THR99, PRO100
# ALA91 -> LEU98
# ILE92 -> LEU39, ARG118
# SER93 -> GLU96, LEU98
# LYS94 -> GLU96, VAL97, LEU98
# SER122 -> ASN37, SER166
# CYS123 -> TYR168
# ASP124 -> TYR168
# ARG137 -> TYR168
# TRP143 -> TRP53, THR99, MET114
# THR144 -> SER75, LEU102, ARG104
# HIS145 -> SER75, ARG104
# HIS146 -> ARG104
# GLU149 -> ARG3, ARG104
# TYR185 -> TYR164
# SER186 -> GLU163, TYR164
# CYS187 -> GLN55, MET114, TYR164
# Shape of E and A: (3278,)
# Shape of E and A: (3278,)
# interaction_pair: {((np.int64(92), np.str_('ILE')), (np.int64(118), np.str_('ARG'))), ((np.int64(187), np.str_('CYS')), (np.int64(55), np.str_('GLN'))), ((np.int64(87), np.str_('ALA')), (np.int64(100), np.str_('PRO'))), ((np.int64(94), np.str_('LYS')), (np.int64(98), np.str_('LEU'))), ((np.int64(85), np.str_('ASP')), (np.int64(102), np.str_('LEU'))), ((np.int64(93), np.str_('SER')), (np.int64(96), np.str_('GLU'))), ((np.int64(144), np.str_('THR')), (np.int64(75), np.str_('SER'))), ((np.int64(91), np.str_('ALA')), (np.int64(98), np.str_('LEU'))), ((np.int64(15), np.str_('ARG')), (np.int64(4), np.str_('ALA'))), ((np.int64(146), np.str_('HIS')), (np.int64(104), np.str_('ARG'))), ((np.int64(44), np.str_('ILE')), (np.int64(170), np.str_('ARG'))), ((np.int64(44), np.str_('ILE')), (np.int64(209), np.str_('ILE'))), ((np.int64(122), np.str_('SER')), (np.int64(166), np.str_('SER'))), ((np.int64(47), np.str_('GLU')), (np.int64(39), np.str_('LEU'))), ((np.int64(186), np.str_('SER')), (np.int64(157), np.str_('GLU'))), ((np.int64(94), np.str_('LYS')), (np.int64(96), np.str_('GLU'))), ((np.int64(23), np.str_('ARG')), (np.int64(2), np.str_('ASP'))), ((np.int64(186), np.str_('SER')), (np.int64(163), np.str_('GLU'))), ((np.int64(46), np.str_('ASN')), (np.int64(168), np.str_('TYR'))), ((np.int64(145), np.str_('HIS')), (np.int64(75), np.str_('SER'))), ((np.int64(185), np.str_('TYR')), (np.int64(164), np.str_('TYR'))), ((np.int64(124), np.str_('ASP')), (np.int64(168), np.str_('TYR'))), ((np.int64(187), np.str_('CYS')), (np.int64(157), np.str_('GLU'))), ((np.int64(123), np.str_('CYS')), (np.int64(168), np.str_('TYR'))), ((np.int64(122), np.str_('SER')), (np.int64(37), np.str_('ASN'))), ((np.int64(149), np.str_('GLU')), (np.int64(3), np.str_('ARG'))), ((np.int64(19), np.str_('ILE')), (np.int64(3), np.str_('ARG'))), ((np.int64(21), np.str_('THR')), (np.int64(3), np.str_('ARG'))), ((np.int64(23), np.str_('ARG')), (np.int64(3), np.str_('ARG'))), ((np.int64(144), np.str_('THR')), (np.int64(104), np.str_('ARG'))), ((np.int64(17), np.str_('ASP')), (np.int64(7), np.str_('LEU'))), ((np.int64(94), np.str_('LYS')), (np.int64(97), np.str_('VAL'))), ((np.int64(149), np.str_('GLU')), (np.int64(104), np.str_('ARG'))), ((np.int64(186), np.str_('SER')), (np.int64(164), np.str_('TYR'))), ((np.int64(86), np.str_('LEU')), (np.int64(100), np.str_('PRO'))), ((np.int64(143), np.str_('TRP')), (np.int64(53), np.str_('TRP'))), ((np.int64(18), np.str_('VAL')), (np.int64(7), np.str_('LEU'))), ((np.int64(187), np.str_('CYS')), (np.int64(164), np.str_('TYR'))), ((np.int64(143), np.str_('TRP')), (np.int64(116), np.str_('SER'))), ((np.int64(93), np.str_('SER')), (np.int64(98), np.str_('LEU'))), ((np.int64(85), np.str_('ASP')), (np.int64(100), np.str_('PRO'))), ((np.int64(18), np.str_('VAL')), (np.int64(4), np.str_('ALA'))), ((np.int64(187), np.str_('CYS')), (np.int64(114), np.str_('MET'))), ((np.int64(137), np.str_('ARG')), (np.int64(168), np.str_('TYR'))), ((np.int64(145), np.str_('HIS')), (np.int64(104), np.str_('ARG'))), ((np.int64(15), np.str_('ARG')), (np.int64(8), np.str_('TYR'))), ((np.int64(143), np.str_('TRP')), (np.int64(114), np.str_('MET'))), ((np.int64(144), np.str_('THR')), (np.int64(102), np.str_('LEU'))), ((np.int64(143), np.str_('TRP')), (np.int64(99), np.str_('THR')))}
# ARG15 -> ALA4, TYR8
# ASP17 -> LEU7
# VAL18 -> ALA4, LEU7
# ILE19 -> ARG3
# THR21 -> ARG3
# ARG23 -> ASP2, ARG3
# ILE44 -> ARG170, ILE209
# ASN46 -> TYR168
# GLU47 -> LEU39
# ASP85 -> PRO100, LEU102
# LEU86 -> PRO100
# ALA87 -> PRO100
# ALA91 -> LEU98
# ILE92 -> ARG118
# SER93 -> GLU96, LEU98
# LYS94 -> GLU96, VAL97, LEU98
# SER122 -> ASN37, SER166
# CYS123 -> TYR168
# ASP124 -> TYR168
# ARG137 -> TYR168
# TRP143 -> TRP53, THR99, MET114, SER116
# THR144 -> SER75, LEU102, ARG104
# HIS145 -> SER75, ARG104
# HIS146 -> ARG104
# GLU149 -> ARG3, ARG104
# TYR185 -> TYR164
# SER186 -> GLU157, GLU163, TYR164
# CYS187 -> GLN55, MET114, GLU157, TYR164

# %%
"""This script iterates over adjacent chain pairs in a cyclic complex (A-B, B-C, C-D, D-E, E-A), 
computes all inter-chain atom-atom distances, and identifies interface atom pairs within 4A.
It then maps these contacts to residue and atom identities and classifies each interaction into 
backbone-backbone, backbone-side-chain, or side-chain-side-chain categories, 
enabling comparison of interface composition across chain pairs. 
"""

chain_list_1 = ['A', 'B', 'C', 'D', 'E']
chain_list_2 = ['B', 'C', 'D', 'E', 'A']

chain_combine = list(zip(chain_list_1, chain_list_2))
print(chain_combine)

dist_pair_together = []
for combi in chain_combine:
    chain_1, chain_2 = combi
    two_chains = one_complex_protein_only[np.isin(one_complex_protein_only.chain_id, [chain_1, chain_2])]
    print(f"Shape of {chain_1} and {chain_2}: {two_chains.shape}")
    
    # check if there is any hydrogens
    # if the shape of only heavy atom is the same with before, that means no hydrogen
    two_chains_heavy = two_chains[np.isin(two_chains.element, ['C', 'N', 'O', 'S'])]
    print(f"Shape of {chain_1} and {chain_2}: {two_chains_heavy.shape}")
    
    # build distance matrix between two adjacent chains
    chain_1 = one_complex_protein_only[one_complex_protein_only.chain_id == chain_1]
    chain_2 = one_complex_protein_only[one_complex_protein_only.chain_id == chain_2]
    chain_1_coord = chain_1.coord
    chain_2_coord = chain_2.coord
    diff = chain_1_coord[None,:,:] - chain_2_coord[:,None,:]
    dist = np.linalg.norm(diff, axis=-1)
    I, J = np.where(dist < 4) # I, J are array index
    
    # Extract the resn and resi
    # print(f"chain_1.res_id: {chain_1.res_id}")
    chain_1_resid_list = [(chain_1.res_id[j], chain_1.res_name[j], chain_1.atom_name[j]) for j in J]
    chain_2_resid_list = [(chain_2.res_id[i], chain_2.res_name[i], chain_2.atom_name[i]) for i in I]
    interaction_pair = set(list(zip(chain_1_resid_list, chain_2_resid_list)))
    # print(f"interaction_pair: {interaction_pair}")
    
    # if the both atom in a pair is from N, O, C or CA then it is between backbone to backbone
    bb_interaction_pair = []
    bb_sc_interaction_pair = []
    sc_sc_interaction_pair = []
    for pair in interaction_pair:
        chain_1_atom, chain_2_atom = pair
        if np.isin(chain_1_atom[2], ['N', 'O', 'C', 'CA']) and np.isin(chain_2_atom[2], ['N', 'O', 'C', 'CA']):
            bb_interaction_pair.append(pair)
        elif np.isin(chain_2_atom[2], ['N', 'O', 'C', 'CA']) or np.isin(chain_1_atom[2], ['N', 'O', 'C', 'CA']):
            bb_sc_interaction_pair.append(pair)
        elif not np.isin(chain_2_atom[2], ['N', 'O', 'C', 'CA']) and not np.isin(chain_1_atom[2], ['N', 'O', 'C', 'CA']):
            sc_sc_interaction_pair.append(pair)
            
    # print(f"bb_interaction_pair: {bb_interaction_pair}")
    # print(f"bb_sc_interaction_pair: {bb_sc_interaction_pair}")
    # print(f"sc_sc_interaction_pair: {sc_sc_interaction_pair}")
    
    counts = {
    "BB-BB": len(bb_interaction_pair),
    "BB-SC": len(bb_sc_interaction_pair),
    "SC-SC": len(sc_sc_interaction_pair),
    }
    
    print(f"counts: {counts}")
# Out:
# [('A', 'B'), ('B', 'C'), ('C', 'D'), ('D', 'E'), ('E', 'A')]
# Shape of A and B: (3268,)
# Shape of A and B: (3268,)
# counts: {'BB-BB': 0, 'BB-SC': 52, 'SC-SC': 85}
# Shape of B and C: (3220,)
# Shape of B and C: (3220,)
# counts: {'BB-BB': 0, 'BB-SC': 57, 'SC-SC': 82}
# Shape of C and D: (3246,)
# Shape of C and D: (3246,)
# counts: {'BB-BB': 0, 'BB-SC': 44, 'SC-SC': 79}
# Shape of D and E: (3232,)
# Shape of D and E: (3232,)
# counts: {'BB-BB': 1, 'BB-SC': 57, 'SC-SC': 88}
# Shape of E and A: (3278,)
# Shape of E and A: (3278,)
# counts: {'BB-BB': 1, 'BB-SC': 55, 'SC-SC': 97}

# %%
"""
We could also iterate through the chain pair,
calculate the inter-chain atom-atom distance,
classify atom-atom contact into BB-BB, BB-SC, SC-SC,
store the result into b-factor
"""

import numpy as np
import biotite.structure as structure


atom_array = one_complex_protein_only
n_atom = len(atom_array)

b_factor = np.zeros(n_atom, dtype=float)

chain_list_1 = ['A', 'B', 'C', 'D', 'E']
chain_list_2 = ['B', 'C', 'D', 'E', 'A']

chain_combi = list(zip(chain_list_1, chain_list_2))

global_interaction_pair = set()
for combi in chain_combi:
    mask_chain1 = atom_array.chain_id == combi[0]
    mask_chain2 = atom_array.chain_id == combi[1]
    chain1 = atom_array[mask_chain1]
    chain2 = atom_array[mask_chain2]
    # return the location of array where True
    # used as a way to reflect the global index loccation
    print(np.where(mask_chain1)) 
    global_mask_chain1 = np.where(mask_chain1)[0] # 100, 101, 102,...
    global_mask_chain2 = np.where(mask_chain2)[0] # 300, 301, 302, ...
    
    # calculate the distance matrix
    diff = chain1.coord[None,:,:] - chain2.coord[:,None,:]
    dist = np.linalg.norm(diff, axis=-1)
    I, J = np.where(dist < 4) # 1, 2, 3, ...
    global_I = [global_mask_chain2[i] for i in I] # 100, 101, 102,...
    global_J = [global_mask_chain1[j] for j in J]
    for pair in list(zip(global_I, global_J)):
        global_interaction_pair.add(pair)
    
print(global_interaction_pair)
    
def check_backbone(atom_name):
    return atom_name in {'N', 'CA', 'C', 'O', 'OXT'}
    
bb_interaction = []
bb_sc_interaction = []
sc_sc_interaction = []

for pair in global_interaction_pair:
    pair_0 = check_backbone(atom_array[pair[0]].atom_name)
    pair_1 = check_backbone(atom_array[pair[1]].atom_name)
    
    if pair_0 == True and pair_1 == True:
        bb_interaction.append(pair)
        b_factor[pair[0]] = 0
        b_factor[pair[1]] = 0
    elif pair_0 == False and pair_1 == False:
        sc_sc_interaction.append(pair)
        b_factor[pair[0]] = 10
        b_factor[pair[1]] = 10
    else:
        bb_sc_interaction.append(pair)
        
print(bb_interaction)

atom_array.set_annotation("b_factor", b_factor)

pdb = PDBFile()
pdb.set_structure(atom_array)
pdb.write("interface_colored.pdb")
# Out:
# (array([   0,    1,    2, ..., 1667, 1668, 1669], shape=(1670,)),)
# (array([1670, 1671, 1672, ..., 3265, 3266, 3267], shape=(1598,)),)
# (array([3268, 3269, 3270, ..., 4887, 4888, 4889], shape=(1622,)),)
# (array([4890, 4891, 4892, ..., 6511, 6512, 6513], shape=(1624,)),)
# (array([6514, 6515, 6516, ..., 8119, 8120, 8121], shape=(1608,)),)
# {(np.int64(7455), np.int64(5627)), (np.int64(7823), np.int64(5883)), (np.int64(1327), np.int64(6885)), (np.int64(5830), np.int64(4005)), (np.int64(5662), np.int64(4021)), (np.int64(769), np.int64(7268)), (np.int64(3700), np.int64(2799)), (np.int64(7818), np.int64(5261)), (np.int64(2980), np.int64(352)), (np.int64(3294), np.int64(2852)), (np.int64(2503), np.int64(1181)), (np.int64(5796), np.int64(4393)), (np.int64(4174), np.int64(2794)), (np.int64(5502), np.int64(4413)), (np.int64(3290), np.int64(1826)), (np.int64(5341), np.int64(4743)), (np.int64(7331), np.int64(5578)), (np.int64(2464), np.int64(1128)), (np.int64(4916), np.int64(4450)), (np.int64(7842), np.int64(5245)), (np.int64(2504), np.int64(1182)), (np.int64(4912), np.int64(3424)), (np.int64(7819), np.int64(5261)), (np.int64(1284), np.int64(7974)), (np.int64(4585), np.int64(2657)), (np.int64(7306), np.int64(6015)), (np.int64(30), np.int64(6640)), (np.int64(941), np.int64(7253)), (np.int64(6183), np.int64(4258)), (np.int64(2611), np.int64(737)), (np.int64(833), np.int64(7647)), (np.int64(5662), np.int64(4016)), (np.int64(2947), np.int64(979)), (np.int64(7315), np.int64(5593)), (np.int64(21), np.int64(6704)), (np.int64(4098), np.int64(2803)), (np.int64(2960), np.int64(369)), (np.int64(7348), np.int64(6044)), (np.int64(5677), np.int64(4013)), (np.int64(6539), np.int64(5088)), (np.int64(832), np.int64(7696)), (np.int64(25), np.int64(6701)), (np.int64(2464), np.int64(1123)), (np.int64(5682), np.int64(4393)), (np.int64(4060), np.int64(2794)), (np.int64(22), np.int64(6704)), (np.int64(2487), np.int64(688)), (np.int64(4101), np.int64(2850)), (np.int64(7420), np.int64(6014)), (np.int64(4947), np.int64(3395)), (np.int64(7455), np.int64(5626)), (np.int64(776), np.int64(7270)), (np.int64(4584), np.int64(2656)), (np.int64(1331), np.int64(7501)), (np.int64(3293), np.int64(1840)), (np.int64(7775), np.int64(6336)), (np.int64(4587), np.int64(2661)), (np.int64(5662), np.int64(4011)), (np.int64(4603), np.int64(2022)), (np.int64(7346), np.int64(6070)), (np.int64(3320), np.int64(1812)), (np.int64(2102), np.int64(1129)), (np.int64(906), np.int64(7641)), (np.int64(5800), np.int64(4744)), (np.int64(4569), np.int64(2649)), (np.int64(1694), np.int64(1182)), (np.int64(2471), np.int64(703)), (np.int64(792), np.int64(7637)), (np.int64(6571), np.int64(5017)), (np.int64(5502), np.int64(4403)), (np.int64(2503), np.int64(1180)), (np.int64(4540), np.int64(3116)), (np.int64(2504), np.int64(1154)), (np.int64(299), np.int64(7493)), (np.int64(2965), np.int64(991)), (np.int64(1695), np.int64(198)), (np.int64(6965), np.int64(6341)), (np.int64(4037), np.int64(2424)), (np.int64(4552), np.int64(3117)), (np.int64(7823), np.int64(5877)), (np.int64(1284), np.int64(7973)), (np.int64(1336), np.int64(7593)), (np.int64(30), np.int64(6639)), (np.int64(7306), np.int64(6014)), (np.int64(2576), np.int64(1124)), (np.int64(1298), np.int64(7975)), (np.int64(5320), np.int64(4395)), (np.int64(2611), np.int64(736)), (np.int64(6540), np.int64(6072)), (np.int64(7347), np.int64(6033)), (np.int64(6536), np.int64(5046)), (np.int64(4055), np.int64(2414)), (np.int64(31), np.int64(6640)), (np.int64(3298), np.int64(1797)), (np.int64(6539), np.int64(5060)), (np.int64(2960), np.int64(368)), (np.int64(7838), np.int64(5242)), (np.int64(26), np.int64(7693)), (np.int64(5677), np.int64(4012)), (np.int64(430), np.int64(7643)), (np.int64(2916), np.int64(1484)), (np.int64(5722), np.int64(4401)), (np.int64(6574), np.int64(5017)), (np.int64(4540), np.int64(3111)), (np.int64(25), np.int64(6700)), (np.int64(4101), np.int64(2813)), (np.int64(4174), np.int64(2797)), (np.int64(5684), np.int64(4393)), (np.int64(832), np.int64(7695)), (np.int64(24), np.int64(6704)), (np.int64(1349), np.int64(6866)), (np.int64(4552), np.int64(3103)), (np.int64(4942), np.int64(3410)), (np.int64(7126), np.int64(6024)), (np.int64(4552), np.int64(3112)), (np.int64(2487), np.int64(687)), (np.int64(7126), np.int64(6033)), (np.int64(7314), np.int64(5577)), (np.int64(2592), np.int64( ...
# [(np.int64(7818), np.int64(5250)), (np.int64(1665), np.int64(6866))]

# %%
# Add b-factor per residue all together
# plot b-factor matrix using chain-resi-index vs chain-resi-index
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

print(atom_array.chain_id)
print(atom_array.res_id)

chain_res = np.array([
    f"{c}{r}" for c, r in zip(atom_array.chain_id, atom_array.res_id)
])
print(chain_res)

val, count = np.unique(chain_res, return_counts=True)
print(val, count)

atom_array.set_annotation("chain_res", chain_res)

print(atom_array.chain_res)

b_factor = atom_array.b_factor

bf_sum = defaultdict(float)
for cr, bf in zip(chain_res, b_factor):
    bf_sum[cr] += bf
    
print(bf_sum)

# write the residue b_factor score back to structure
bf_sum_atom = np.array([bf_sum[cr] for cr in chain_res])
atom_array.set_annotation("residue_b_factor", bf_sum_atom)
# Out:
# ['A' 'A' 'A' ... 'E' 'E' 'E']
# [  1   1   1 ... 204 204 204]
# ['A1' 'A1' 'A1' ... 'E204' 'E204' 'E204']
# ['A1' 'A10' 'A100' ... 'E97' 'E98' 'E99'] [8 8 7 ... 7 8 7]
# ['A1' 'A1' 'A1' ... 'E204' 'E204' 'E204']
# defaultdict(<class 'float'>, {np.str_('A1'): np.float64(0.0), np.str_('A2'): np.float64(30.0), np.str_('A3'): np.float64(60.0), np.str_('A4'): np.float64(10.0), np.str_('A5'): np.float64(0.0), np.str_('A6'): np.float64(0.0), np.str_('A7'): np.float64(20.0), np.str_('A8'): np.float64(10.0), np.str_('A9'): np.float64(0.0), np.str_('A10'): np.float64(0.0), np.str_('A11'): np.float64(0.0), np.str_('A12'): np.float64(0.0), np.str_('A13'): np.float64(0.0), np.str_('A14'): np.float64(0.0), np.str_('A15'): np.float64(10.0), np.str_('A16'): np.float64(0.0), np.str_('A17'): np.float64(10.0), np.str_('A18'): np.float64(0.0), np.str_('A19'): np.float64(10.0), np.str_('A20'): np.float64(0.0), np.str_('A21'): np.float64(10.0), np.str_('A22'): np.float64(0.0), np.str_('A23'): np.float64(0.0), np.str_('A24'): np.float64(10.0), np.str_('A25'): np.float64(0.0), np.str_('A26'): np.float64(0.0), np.str_('A27'): np.float64(0.0), np.str_('A28'): np.float64(0.0), np.str_('A29'): np.float64(0.0), np.str_('A30'): np.float64(0.0), np.str_('A31'): np.float64(0.0), np.str_('A32'): np.float64(0.0), np.str_('A33'): np.float64(0.0), np.str_('A34'): np.float64(0.0), np.str_('A35'): np.float64(0.0), np.str_('A36'): np.float64(0.0), np.str_('A37'): np.float64(10.0), np.str_('A38'): np.float64(0.0), np.str_('A39'): np.float64(10.0), np.str_('A40'): np.float64(0.0), np.str_('A41'): np.float64(0.0), np.str_('A42'): np.float64(0.0), np.str_('A43'): np.float64(0.0), np.str_('A44'): np.float64(10.0), np.str_('A45'): np.float64(0.0), np.str_('A46'): np.float64(10.0), np.str_('A47'): np.float64(10.0), np.str_('A48'): np.float64(0.0), np.str_('A49'): np.float64(0.0), np.str_('A50'): np.float64(0.0), np.str_('A51'): np.float64(0.0), np.str_('A52'): np.float64(0.0), np.str_('A53'): np.float64(30.0), np.str_('A54'): np.float64(0.0), np.str_('A55'): np.float64(10.0), np.str_('A56'): np.float64(0.0), np.str_('A57'): np.float64(0.0), np.str_('A58'): np.float64(0.0), np.str_('A59'): np.float64(0.0), np.str_('A60'): np.float64(0.0), np.str_('A61'): np.float64(0.0), np.str_('A62'): np.float64(0.0), np.str_('A63'): np.float64(0.0), np.str_('A64'): np.float64(0.0), np.str_('A65'): np.float64(0.0), np.str_('A66'): np.float64(0.0), np.str_('A67'): np.float64(0.0), np.str_('A68'): np.float64(0.0), np.str_('A69'): np.float64(0.0), np.str_('A70'): np.float64(0.0), np.str_('A71'): np.float64(0.0), np.str_('A72'): np.float64(0.0), np.str_('A73'): np.float64(0.0), np.str_('A74'): np.float64(0.0), np.str_('A75'): np.float64(20.0), np.str_('A76'): np.float64(0.0), np.str_('A77'): np.float64(0.0), np.str_('A78'): np.float64(0.0), np.str_('A79'): np.float64(0.0), np.str_('A80'): np.float64(0.0), np.str_('A81'): np.float64(0.0), np.str_('A82'): np.float64(0.0), np.str_('A83'): np.float64(0.0), np.str_('A84'): np.float64(0.0), np.str_('A85'): np.float64(30.0), np.str_('A86'): np.float64(0.0), np.str_('A87'): np.float64(10.0), np.str_('A88'): np.float64(0.0), np.str_('A89'): np.float64(0.0), np.str_('A90'): np.float64(0.0), np.str_('A91'): np.float64(0.0), np.str_('A92'): np.float64(10.0), np.str_('A93'): np.float64(0.0), np.str_('A94'): np.float64(30.0), np.str_('A95'): np.float64(0.0), np.str_('A96'): np.float64(20.0), np.str_('A97'): np.float64(0.0), np.str_('A98'): np.float64(0.0), np.str_('A99'): np.float64(30.0), np.str_('A100'): np.float64(30.0), np.str_('A101'): np.float64(0.0), np.str_('A102'): np.float64(10.0), np.str_('A103'): np.float64(0.0), np.str_('A104'): np.float64(30.0), np.str_('A105'): np.float64(0.0), np.str_('A106'): np.float64(0.0), np.str_('A107'): np.float64(0.0), np.str_('A108'): np.float64(0.0), np.str_('A109'): np.float64(0.0), np.str_('A110'): np.float64(0.0), np.str_('A111'): np.float64(0.0), np.str_('A112'): np.float64(0.0), np.str_('A113'): np.float64(0.0), np.str_('A114'): np.float64(10.0), np.str_('A115'): np.float64(0.0), np.str_('A116'): np.float64(10.0), np.str_('A117'): np.float64(0.0), np.str_('A118'): np.float64(10.0), np.str_('A119'): np.float64(0.0), np ...

# %%
# plot x-chain_res, y-bf_sum, one chain per plot
# for each chain, rank based on chain_res(based on the number of res as interger), for example 1, 2,3, but still show chain_res in x-axis
# and only plot when bf_sum>0

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

chain_res = atom_array.chain_res
b_factor = atom_array.residue_b_factor
df = pd.DataFrame({
    "chain_res": chain_res,
    "residue_b_factor": b_factor
})
df = df[df['residue_b_factor'] > 0]
df['res_num'] = df['chain_res'].str[1:].astype(int)
df = df.sort_values(by=['chain_res', 'res_num'])
plt.figure(figsize=(30, 6))
sns.barplot(data=df, x='chain_res', y='residue_b_factor', palette='viridis')
plt.xticks(rotation=90)
plt.xlabel('Residue (Chain + Resi)')
plt.ylabel('Sum of B-Factor Scores')
plt.title('Residue Interaction B-Factor Scores')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_301583/2413479444.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='chain_res', y='residue_b_factor', palette='viridis')

# %% [markdown]
# - The calculation using previous method has complexity of X(N1*N2), which is ok for small system.
# - When system is getting larger, using CellList is a better way.
# - The idea of CellList is:
# 1. Cut the space into small cells
# 2. Each atom put into small cells.
# 3. When check neighbors, only check the current cell and neighbor cell, and ignore the box in a distance.
# 4. The complexity is closer to O(1)

# %%
from biotite.structure import CellList

cell = CellList(atom_array, cell_size=4.0)

interface_mask = np.zeros(len(atom_array), dtype=bool)

for i, coord in enumerate(atom_array.coord):
    neighbors = cell.get_atoms(coord, radius=4.0)
    print(f"atom {i} neighbors: {neighbors}")
    # remove itself
    neighbors = neighbors[neighbors != -1]

    # if any neighbor atom belongs to a different chain, mark as interface atom
    if np.any(atom_array.chain_id[neighbors] != atom_array.chain_id[i]):
        interface_mask[i] = True
        print(f"atom {i} is at the interface.")
        # Set b-factor for interface atoms
        b_factor[i] = 20
    else:
        print(f"atom {i} is not at the interface.")
        b_factor[i] = 0
atom_array.set_annotation("b_factor", b_factor)
pdb = PDBFile()
pdb.set_structure(atom_array)
pdb.write("interface_colored_celllist.pdb")
# Out:
# atom 0 neighbors: [  5   7   0   1   4 575   2   3   8]
# atom 0 is not at the interface.
# atom 1 neighbors: [  5   6   7   0   1   4 575   2   3   8   9]
# atom 1 is not at the interface.
# atom 2 neighbors: [ 5  0  1  4  2  3  8 10 11  9 12]
# atom 2 is not at the interface.
# atom 3 neighbors: [  0   1   4 571 574 575   2   3   8  10 563   9  12 582]
# atom 3 is not at the interface.
# atom 4 neighbors: [  5   6   7   0   1   4 574 575   2   3   8]
# atom 4 is not at the interface.
# atom 5 neighbors: [5 6 7 0 1 4 2]
# atom 5 is not at the interface.
# atom 6 neighbors: [  5   6   7   1   4 543]
# atom 6 is not at the interface.
# atom 7 neighbors: [ 5  6  7  0  1  4 36]
# atom 7 is not at the interface.
# atom 8 neighbors: [ 0  1  4 39  2  3  8 10 11 14  9 12 13 16]
# atom 8 is not at the interface.
# atom 9 neighbors: [ 1  2  3  8 10 11 14  9 12 13 15 16 17]
# atom 9 is not at the interface.
# atom 10 neighbors: [ 2  3  8 10 11 14 32  9 12 13 16 17 18 19 20 27]
# atom 10 is not at the interface.
# atom 11 neighbors: [36 45 34 40 41  2  8 10 11 14 33 29 32  9 12 13 44 47 16 17 18 19 27]
# atom 11 is not at the interface.
# atom 12 neighbors: [   2    3    8   10   11   14    9   12   13   15 6705   16 6703 6704]
# atom 12 is at the interface.
# atom 13 neighbors: [  37   39    8   10   11   14    9   12   13   15 6705   16   27]
# atom 13 is at the interface.
# atom 14 neighbors: [36 37 39 38  8 10 11 14 33 28 29 31 32  9 12 13 15 16 27]
# atom 14 is not at the interface.
# atom 15 neighbors: [  39   14    9   12   13   15 6705]
# atom 15 is at the interface.
# atom 16 neighbors: [   8   10   11   14    9   12   13 6705   16   17   18   19   20   21
#    27 6703 6704]
# atom 16 is at the interface.
# atom 17 neighbors: [  10   11   28    9   16   17   18   19   20   21   27 6704   22]
# atom 17 is at the interface.
# atom 18 neighbors: [40 10 11 28 29 30 31 32 16 17 18 19 20 21 27]
# atom 18 is not at the interface.
# atom 19 neighbors: [34 40 41 10 11 28 29 30 32 42 44 48 49 52 53 16 17 18 19 20 27 54]
# atom 19 is not at the interface.
# atom 20 neighbors: [  10   16   17   18   19   20   21   27 6704   22   23]
# atom 20 is at the interface.
# atom 21 neighbors: [  16   17   18   20   21  581 6704   24   22   23   25]
# atom 21 is at the interface.
# atom 22 neighbors: [  17   20   21 6704   24   26   22   23   25 6670 6684]
# atom 22 is at the interface.
# atom 23 neighbors: [20 21 24 26 22 23 25]
# atom 23 is not at the interface.
# atom 24 neighbors: [  21 6704   24   26   22   23   25 6684]
# atom 24 is at the interface.
# atom 25 neighbors: [  21 6703 6704 6700 6701   24   26   22   23   25 6684]
# atom 25 is at the interface.
# atom 26 neighbors: [  24   26   22   23   25 7693 7694 7696]
# atom 26 is at the interface.
# atom 27 neighbors: [10 11 14 28 29 30 31 32 13 16 17 18 19 20 27]
# atom 27 is not at the interface.
# atom 28 neighbors: [  14   33   28   29   30   31   32 6640   17   18   19   27 6663]
# atom 28 is at the interface.
# atom 29 neighbors: [  36   34   35   40   11   14   33   28   29   30   31   32 6640   48
#    18   19   27]
# atom 29 is at the interface.
# atom 30 neighbors: [  34   35   40   56   57   60   33   28   29   30   31   32 6639 6640
#    48   50 6641   18   19   27]
# atom 30 is at the interface.
# atom 31 neighbors: [  14   28   29   30   31   32 6640   18   27]
# atom 31 is at the interface.
# atom 32 neighbors: [36 37 39 38 34 35 40 10 11 14 33 28 29 30 31 32 18 19 27]
# atom 32 is not at the interface.
# atom 33 neighbors: [36 37 39 38 34 35 40 41 11 14 33 28 29 30 32]
# atom 33 is not at the interface.
# atom 34 neighbors: [36 37 34 35 40 41 56 11 33 29 30 32 42 43 44 48 19]
# atom 34 is not at the interface.
# atom 35 neighbors: [73 75 74 36 72 58 68 69 34 35 40 41 56 57 60 33 29 30 32 42 43 48]
# atom 35 is not at the interface.
# atom 36 neighbors: [ 7 36 37 39 38 34 35 40 11 14 33 29 32]
# atom 36 is not at the interface.
# atom 37 neighbors: [36 37 39 38 34 14 33 32 13]
# atom 37 is not at the interface.
# atom 38 neighbors: [36 37 39 38 14 33 32]
# atom 38 is not at the interface.
# atom 39 neighbors: [36 37 39 38  8 14 33 32 13 15]
# atom 39 is not at the interface.
# atom 40 neighbors: [36 45 34 35 40 41 11 33 29 30 32 42 43 44 46 48 18 19]
# atom 40 is not at the interface.
# atom 41 neighbors: [45 34 35 40 41 11 33 42 43 44 46 48 49 47 19]
# atom 41 is not at the interface.
# atom 42 neighbors: [68 45 34 35 40 41 56 51 42 43 44 46 48 49 50 52 19]
# atom 42 is not at the interface.
# atom 43 neighbors: [72 68 69 70 76 34 35 40 41 56 80 81 83 51 77 42 43 44 46 48 49 50]
# atom 43 is not at the interface.
# atom 44 neighbors: [45 34 40 41 11 42 43 44 46 48 47 19]
# atom 44 is not at the interface.
# atom 45 neighbors: [45 40 41 11 42 44 46 47]
# atom 45 is not at the interface.
# atom 46 neighbors: [ 45  40  41 536 538  83  42  43  44  46  48  47]
# atom 46 is not at the interface.
# atom 47 neighbors: [ 45  41  11 534 535  44  46 579  47]
# atom 47 is not at the interface.
# atom 48 neighbors: [34 35 40 41 56 29 30 51 42 43 44 46 48 49 50 52 53 19]
# atom 48 is not at the interface.
# atom 49 neighbors: [41 56 57 51 42 43 48 49 50 52 53 19 55 54]
# atom 49 is not at the interface.
# atom 50 neighbors: [58 59 68 76 56 57 60 30 51 42 43 48 49 50 52 53]
# atom 50 is not at the interface.
# atom 51 neighbors: [58 59 68 76 56 57 78 80 51 77 84 85 88 42 43 48 49 50 52]
# atom 51 is not at the interface.
# atom 52 neighbors: [  56   51   42   48   49   50   52   53 6656   19   55   54]
# atom 52 is at the interface.
# atom 53 neighbors: [48 49 50 52 53 19 55 54]
# atom 53 is not at the interface.
# atom 54 neighbors: [  49   52   53   19 6663   55   54 6652 6658]
# atom 54 is at the interface.
# atom 55 neighbors: [ 49  52  53 619  55  54 610]
# atom 55 is not at the interface.
# atom 56 neighbors: [  58   59   68   34   35   56   57   60   61   30   51   42   43   48
#    49   50   52 6641]
# atom 56 is at the interface.
# atom 57 neighbors: [  63   58   59   68   69   35   56   57   60   61   62   30   51   49
#    50 6641]
# atom 57 is at the interface.
# atom 58 neighbors: [63 71 72 58 59 68 69 70 76 35 56 57 60 61 62 51 84 50]
# atom 58 is not at the interface.
# atom 59 neighbors: [ 63  71  95  96  99  58  59  68  69  70  76 100  56  57  60  61  86  51
#   84  85  88  50]
# atom 59 is not at the interface.
# atom 60 neighbors: [  65   63   64   58   59   68   35   56   57   60   61   62   30   50
#  6641]
# atom 60 is at the interface.
# atom 61 neighbors: [65 66 63 64 58 59 68 56 57 60 61 62]
# atom 61 is not at the interface.
# atom 62 neighbors: [65 66 67 63 64 58 57 60 61 62]
# atom 62 is not at the interface.
# atom 63 neighbors: [74 65 66 67 63 64 58 59 68 57 60 61 62]
# atom 63 is not at the interface.
# atom 64 neighbors: [ 65  66  67  63  64 100  60  61  62]
# atom 64 is not at the interface.
# atom 65 neighbors: [ 65  66  67  63  64 100  60  61  62]
# atom 65 is not at the interface.
# atom 66 neighbors: [ 65  66  67  63  64 100  61  62]
# atom 66 is not at the interface.
# atom 67 neighbors: [102  65  66  67  63  64  62]
# atom 67 is not at the interface.
# atom 68 neighbors: [73 74 63 71 72 58 59 68 69 70 76 35 56 57 60 61 51 42 43 50]
# atom 68 is not at the interface.
# atom 69 neighbors: [73 75 74 71 72 58 59 68 69 70 76 35 57 77 43]
# atom 69 is not at the interface.
# atom 70 neighbors: [73 71 95 72 58 59 68 69 70 76 78 79 80 77 84 43]
# atom 70 is not at the interface.
# atom 71 neighbors: [110 105 109  71  97 104 108  95  96  99  72  58  59  68  69  70  76  78
#   79  77  84]
# atom 71 is not at the interface.
# atom 72 neighbors: [73 75 74 71 72 58 68 69 70 76 35 43]
# atom 72 is not at the interface.
# atom 73 neighbors: [73 75 74 72 68 69 70 35]
# atom 73 is not at the interface.
# atom 74 neighbors: [73 75 74 63 72 68 69 35]
# atom 74 is not at the interface.
# atom 75 neighbors: [73 75 74 72 69 35]
# atom 75 is not at the interface.
# atom 76 neighbors: [71 72 58 59 68 69 70 76 78 79 80 81 51 77 82 84 43 50]
# atom 76 is not at the interface.
# atom 77 neighbors: [71 69 70 76 78 79 80 81 83 51 77 82 84 85 43]
# atom 77 is not at the interface.
# atom 78 neighbors: [ 71 104  95  70  76 111  78  79  86  87  80  81  51  77  82  84  85  88]
# atom 78 is not at the interface.
# atom 79 neighbors: [106  71 104  95  70  76 111 112  78  79 115  86  87  80  77  82  84  85]
# atom 79 is not at the interface.
# atom 80 neighbors: [70 76 78 79 80 81 83 51 77 82 84 43]
# atom 80 is not at the interface.
# atom 81 neighbors: [76 78 80 81 83 77 82 43]
# atom 81 is not at the interface.
# atom 82 neighbors: [76 78 79 80 81 83 77 82 84]
# atom 82 is not at the interface.
# atom 83 neighbors: [80 81 83 77 82 43 46]
# atom 83 is not at the interface.
# atom 84 neighbors: [71 95 58 59 70 76 78 79 86 87 80 51 77 82 84 85 88 89]
# atom 84 is not at the interface.
# atom 85 neighbors: [95 96 59 78 79 86 87 51 77 84 85 88 89 90]
# atom 85 is not at the interface.
# atom 86 neighbors: [ 97 104  95  96  99  59  78  79  86  87  84  85  88  89]
# atom 86 is not at the interface.
# atom 87 neighbors: [ 97 104  95  96  98  78  79  86  87  84  85  88  89]
# atom 87 is not at the interface.
# atom 88 neighbors: [95 59 78 86 87 51 84 85 88 89 90 91]
# atom 88 is not at the interface.
# atom 89 neighbors: [95 86 87 84 85 88 89 90 91 92 93]
# atom 89 is not at the interface.
# atom 90 neighbors: [85 88 89 90 91 92 93 94]
# atom 90 is not at the interface.
# atom 91 neighbors: [88 89 90 91 92 93 94]
# atom 91 is not at the interface.
# atom 92 neighbors: [89 90 91 92 93 94]
# atom 92 is not at the interface.
# atom 93 neighbors: [89 90 91 92 93 94]
# atom 93 is not at the interface.
# atom 94 neighbors: [90 91 92 93 94]
# atom 94 is not at the interface.
# atom 95 neighbors: [101  71  97 104  95  96  98  99  59  70 100 103  78  79  86  87  84  85
#   88  89]
# atom 95 is not at the interface.
# atom 96 neighbors: [102 101 105  71  97 104  95  96  98  99  59 100 103  86  87  85]
# atom 96 is not at the interface.
# atom 97 neighbors: [110 105 106  71  97 104 108  95  96  98  99 100 111  86  87]
# atom 97 is not at the interface.
# atom 98 neighbors: [110 105 106  97 104 108  95  96  98  99  87]
# atom 98 is not at the interface.
# atom 99 neighbors: [102 101  71  97 104  95  96  98  99  59 100 103  86]
# atom 99 is not at the interface.
# atom 100 neighbors: [102  65  66 101  64  97  95  96  99  59 100 103]
# atom 100 is not at the interface.
# atom 101 neighbors: [102 101  95  96  99 100 103]
# atom 101 is not at the interface.
# atom 102 neighbors: [102  67 101  96  99 100 103]
# atom 102 is not at the interface.
# atom 103 neighbors: [102 101  95  96  99 100 103]
# atom 103 is not at the interface.
# atom 104 neighbors: [110 105 106 107 109  71  97 104 108  95  96  98  99 111  78  79  86  87]
# atom 104 is not at the interface.
# atom 105 neighbors: [110 105 106 107 109  71  97 104 108  96  98 111 112]
# atom 105 is not at the interface.
# atom 106 neighbors: [110 105 106 107 109  97 104 108  98 111 112 113 114 117  79 115]
# atom 106 is not at the interface.
# atom 107 neighbors: [105 106 107 109 104 108 122 111 112 113 114 117]
# atom 107 is not at the interface.
# atom 108 neighbors: [110 105 106 107 109  71  97 104 108  98 111]
# atom 108 is not at the interface.
# atom 109 neighbors: [110 105 106 107 109  71 104 108 111]
# atom 109 is not at the interface.
# atom 110 neighbors: [110 105 106 109  71  97 104 108  98]
# atom 110 is not at the interface.
# atom 111 neighbors: [105 106 107 109  97 104 108 111 112 113 114 116 117  78  79 115]
# atom 111 is not at the interface.
# atom 112 neighbors: [105 106 107 118 111 112 113 114 116 117  79 115]
# atom 112 is not at the interface.
# atom 113 neighbors: [106 107 118 121 122 111 112 113 114 116 117 115 119 128 134]
# atom 113 is not at the interface.
# atom 114 neighbors: [106 107 118 121 111 112 113 114 116 117 115 119 128 134]
# atom 114 is not at the interface.
# atom 115 neighbors: [106 111 112 113 114 116 117  79 115 644]
# atom 115 is not at the interface.
# atom 116 neighbors: [111 112 113 114 116 117 520 115 648 643 644]
# atom 116 is not at the interface.
# atom 117 neighbors: [123 106 107 118 121 122 111 112 113 114 116 117 115 119 120 128 134]
# atom 117 is not at the interface.
# atom 118 neighbors: [123 118 121 122 124 141 112 113 114 117 119 120 128 129 134]
# atom 118 is not at the interface.
# atom 119 neighbors: [118 121 122 141 113 114 117 143 119 120 128 129 130 135 132 133 134]
# atom 119 is not at the interface.
# atom 120 neighbors: [147 118 121 141 117 144 143 146 119 120 128 129 130 131 135 134]
# atom 120 is not at the interface.
# atom 121 neighbors: [125 123 147 149 118 121 122 124 141 113 114 117 119 120 128]
# atom 121 is not at the interface.
# atom 122 neighbors: [125 126 123 107 118 121 122 124 113 117 119]
# atom 122 is not at the interface.
# atom 123 neighbors: [125 126 123 127 118 121 122 124 141 117]
# atom 123 is not at the interface.
# atom 124 neighbors: [125 126 123 127 149 140 142 118 121 122 124 141]
# atom 124 is not at the interface.
# atom 125 neighbors: [ 125  126 1700  123  127  149  142  121  122  124  141]
# atom 125 is at the interface.
# atom 126 neighbors: [ 125  126 1700  123  127  122  124]
# atom 126 is at the interface.
# atom 127 neighbors: [1699 1726  125  126 1700 1727 1730  123 1722 1720  127  149  140  142
#   124  141]
# atom 127 is at the interface.
# atom 128 neighbors: [118 121 141 113 114 117 119 120 128 129 130 131 135 132 133 134]
# atom 128 is not at the interface.
# atom 129 neighbors: [118 119 120 128 129 130 131 135 136 655 132 133 134 656 649 650]
# atom 129 is not at the interface.
# atom 130 neighbors: [141 137 143 139 119 120 128 129 130 131 135 136 132 133 134 656]
# atom 130 is not at the interface.
# atom 131 neighbors: [137 143 120 128 129 130 131 135 136 132 659 660 661 656]
# atom 131 is not at the interface.
# atom 132 neighbors: [119 128 129 130 131 135 132 133 134 649 650]
# atom 132 is not at the interface.
# atom 133 neighbors: [119 128 129 130 132 133 134 638]
# atom 133 is not at the interface.
# atom 134 neighbors: [118 141 113 114 117 119 120 128 129 130 135 132 133 134]
# atom 134 is not at the interface.
# atom 135 neighbors: [140 141 137 138 143 139 119 120 128 129 130 131 135 136 132 134]
# atom 135 is not at the interface.
# atom 136 neighbors: [140 142 141 144 137 138 143 139 129 130 131 135 136]
# atom 136 is not at the interface.
# atom 137 neighbors: [147 149 140 141 144 145 137 138 143 139 130 131 135 136]
# atom 137 is not at the interface.
# atom 138 neighbors: [ 147  140 1724  144  145  150  137  138  143  139  135  136]
# atom 138 is at the interface.
# atom 139 neighbors: [140 142 141 137 138 143 139 130 135 136]
# atom 139 is not at the interface.
# atom 140 neighbors: [127 149 140 142 124 141 137 138 143 139 135 136]
# atom 140 is not at the interface.
# atom 141 neighbors: [125 123 127 149 140 142 118 121 124 141 137 143 139 119 120 128 130 135
#  136 134]
# atom 141 is not at the interface.
# atom 142 neighbors: [ 125 1722  127  140  142  124  141  139  136]
# atom 142 is at the interface.
# atom 143 neighbors: [147 148 149 140 141 144 145 150 137 138 143 139 146 119 120 130 131 135
#  136]
# atom 143 is not at the interface.
# atom 144 neighbors: [147 148 149 144 145 150 151 137 138 143 146 120 136]
# atom 144 is not at the interface.
# atom 145 neighbors: [147 148 149 152 153 144 145 150 151 137 138 143 158 146 154 661]
# atom 145 is not at the interface.
# atom 146 neighbors: [147 148 152 153 144 145 150 151 143 158 164 146 120 659 660 661]
# atom 146 is not at the interface.
# atom 147 neighbors: [147 148 149 121 144 145 150 137 138 143 146 120]
# atom 147 is not at the interface.
# atom 148 neighbors: [147 148 149 153 144 145 150 143 146]
# atom 148 is not at the interface.
# atom 149 neighbors: [1698  125  147  148  127  149  140  121  124  141  144  145  137  143]
# atom 149 is at the interface.
# atom 150 neighbors: [147 148 152 153 144 145 150 151 156 138 143 158 146 155 154 661 663]
# atom 150 is not at the interface.
# atom 151 neighbors: [152 153 144 145 150 151 156 158 159 164 146 155 157 154 661 663 664]
# atom 151 is not at the interface.
# atom 152 neighbors: [152 153 160 165 145 150 151 156 158 159 162 163 164 146 155 154]
# atom 152 is not at the interface.
# atom 153 neighbors: [148 170 152 153 160 165 145 150 151 156 158 159 164 146 155 154]
# atom 153 is not at the interface.
# atom 154 neighbors: [152 153 145 150 151 156 158 164 155 157 154 663 664]
# atom 154 is not at the interface.
# atom 155 neighbors: [152 153 150 151 156 158 164 224 155 157 154 664 666]
# atom 155 is not at the interface.
# atom 156 neighbors: [1692  152  153  150  151  156  155  157  154]
# atom 156 is at the interface.
# atom 157 neighbors: [ 151  156 1177 1143 1145  155  157  154 1188]
# atom 157 is not at the interface.
# atom 158 neighbors: [152 153 160 165 145 150 151 161 158 159 162 163 164 146 155 154]
# atom 158 is not at the interface.
# atom 159 neighbors: [166 152 153 160 165 151 161 158 159 162 163 164]
# atom 159 is not at the interface.
# atom 160 neighbors: [168 166 167 169 172 152 153 160 165 161 158 159 162 163 164 224]
# atom 160 is not at the interface.
# atom 161 neighbors: [168 166 167 172 160 165 161 158 159 162 163 224]
# atom 161 is not at the interface.
# atom 162 neighbors: [152 160 165 161 158 159 162 163 164 492 493 494]
# atom 162 is not at the interface.
# atom 163 neighbors: [152 160 161 158 159 162 163 164 492 494 665 484]
# atom 163 is not at the interface.
# atom 164 neighbors: [152 153 160 151 158 159 162 163 164 146 224 155 154 667 660 662 664 665]
# atom 164 is not at the interface.
# atom 165 neighbors: [168 170 171 166 167 169 172 152 153 160 165 161 158 159 162 224]
# atom 165 is not at the interface.
# atom 166 neighbors: [168 173 203 170 171 166 167 169 172 160 165 161 159 224]
# atom 166 is not at the interface.
# atom 167 neighbors: [174 181 168 173 177 170 171 176 166 167 169 172 160 165 161]
# atom 167 is not at the interface.
# atom 168 neighbors: [174 181 168 173 170 176 166 167 169 172 160 165 161]
# atom 168 is not at the interface.
# atom 169 neighbors: [168 203 170 171 166 167 169 172 160 165]
# atom 169 is not at the interface.
# atom 170 neighbors: [ 168  170  171 1695  166  167  169  153  165]
# atom 170 is at the interface.
# atom 171 neighbors: [ 203  170  171  166  167  169  165 1177]
# atom 171 is not at the interface.
# atom 172 neighbors: [174 181 168 173 177 203 175 176 166 167 169 172 160 165 161]
# atom 172 is not at the interface.
# atom 173 neighbors: [182 174 181 168 173 177 175 176 166 167 172 178]
# atom 173 is not at the interface.
# atom 174 neighbors: [182 183 185 192 174 181 186 168 173 177 200 175 176 167 172]
# atom 174 is not at the interface.
# atom 175 neighbors: [182 183 184 185 192 174 181 173 200 201 204 205 203 175 176 172]
# atom 175 is not at the interface.
# atom 176 neighbors: [174 181 168 173 177 180 175 176 167 172 178 179]
# atom 176 is not at the interface.
# atom 177 neighbors: [174 173 177 180 176 167 172 178 179]
# atom 177 is not at the interface.
# atom 178 neighbors: [173 177 180 176 178 179]
# atom 178 is not at the interface.
# atom 179 neighbors: [177 180 176 178 179]
# atom 179 is not at the interface.
# atom 180 neighbors: [177 180 500 176 178 179]
# atom 180 is not at the interface.
# atom 181 neighbors: [182 183 184 185 192 174 181 186 168 173 175 176 167 172]
# atom 181 is not at the interface.
# atom 182 neighbors: [182 183 184 185 192 187 174 181 186 173 193 175]
# atom 182 is not at the interface.
# atom 183 neighbors: [197 182 183 184 185 192 174 181 186 196 194 200 193 175]
# atom 183 is not at the interface.
# atom 184 neighbors: [182 183 184 185 192 181 196 194 200 205 193 175]
# atom 184 is not at the interface.
# atom 185 neighbors: [188 182 183 184 185 192 187 174 181 186 175]
# atom 185 is not at the interface.
# atom 186 neighbors: [189 188 182 183 185 187 174 181 186]
# atom 186 is not at the interface.
# atom 187 neighbors: [189 190 191 188 182 185 187 186]
# atom 187 is not at the interface.
# atom 188 neighbors: [189 190 191 188 185 187 186]
# atom 188 is not at the interface.
# atom 189 neighbors: [189 190 191 188 187 186]
# atom 189 is not at the interface.
# atom 190 neighbors: [189 190 191 188 187]
# atom 190 is not at the interface.
# atom 191 neighbors: [189 190 191 188 187]
# atom 191 is not at the interface.
# atom 192 neighbors: [197 198 199 182 183 184 185 192 174 181 195 196 194 200 193 175]
# atom 192 is not at the interface.
# atom 193 neighbors: [197 198 199 182 183 184 192 195 196 194 200 201 193]
# atom 193 is not at the interface.
# atom 194 neighbors: [197 183 184 192 195 196 194 200 201 204 205 193 203 202]
# atom 194 is not at the interface.
# atom 195 neighbors: [ 192  195  196 1173  194  200  201  193  202 1166]
# atom 195 is not at the interface.
# atom 196 neighbors: [197 198 199 183 184 192 195 196 194 200 193]
# atom 196 is not at the interface.
# atom 197 neighbors: [197 198 199 183 192 196 194 193]
# atom 197 is not at the interface.
# atom 198 neighbors: [ 197  198  199  192  196  193 1695]
# atom 198 is at the interface.
# atom 199 neighbors: [197 198 199 192 196 193]
# atom 199 is not at the interface.
# atom 200 neighbors: [183 184 192 174 195 196 194 200 201 204 205 193 203 175 202 211]
# atom 200 is not at the interface.
# atom 201 neighbors: [195 206 194 200 201 204 205 193 203 175 207 202 211 217 212]
# atom 201 is not at the interface.
# atom 202 neighbors: [ 195  194  200  201  204  205  203  202  211  216  217  212 1166  214
#   213  215]
# atom 202 is not at the interface.
# atom 203 neighbors: [194 200 201 204 203 171 175 166 169 172 202 211 217 212 214 213 218]
# atom 203 is not at the interface.
# atom 204 neighbors: [206 194 200 201 204 205 203 175 207 202 211 217]
# atom 204 is not at the interface.
# atom 205 neighbors: [184 206 194 200 201 204 205 175 207 208 202]
# atom 205 is not at the interface.
# atom 206 neighbors: [206 201 204 205 207 208 209 210]
# atom 206 is not at the interface.
# atom 207 neighbors: [206 201 204 205 207 208 209 210 217]
# atom 207 is not at the interface.
# atom 208 neighbors: [206 205 207 208 209 210]
# atom 208 is not at the interface.
# atom 209 neighbors: [206 207 208 209 210]
# atom 209 is not at the interface.
# atom 210 neighbors: [206 207 208 209 210]
# atom 210 is not at the interface.
# atom 211 neighbors: [ 200  201  204  203  202  211  216  217  212 1166  214  213  218  215]
# atom 211 is not at the interface.
# atom 212 neighbors: [ 201  203  202  211  216  217  212 1166 1177  214  213  218  219  215
#  1176]
# atom 212 is not at the interface.
# atom 213 neighbors: [ 203  202  211  216  217  212 1177  214  213  218  219  222  215  220
#   221  225]
# atom 213 is not at the interface.
# atom 214 neighbors: [203 202 211 216 217 212 214 213 218 219 215 220 221 225]
# atom 214 is not at the interface.
# atom 215 neighbors: [ 202  211  216  217  212 1165 1166 1177  214  213  218  215 1160 1176
#  1191]
# atom 215 is not at the interface.
# atom 216 neighbors: [ 202  211  216  217  212 1165 1166  214  213  215 1160]
# atom 216 is not at the interface.
# atom 217 neighbors: [201 204 203 207 202 211 216 217 212 214 213 215]
# atom 217 is not at the interface.
# atom 218 neighbors: [ 203  211  212 1177  214  213  218  219  222  224  223  215 1176  220
#   221  225]
# atom 218 is not at the interface.
# atom 219 neighbors: [ 212 1177  214  213  218  219  222  224  223  220  221  226  225]
# atom 219 is not at the interface.
# atom 220 neighbors: [214 213 218 219 222 224 223 220 221 226 229 225 227 228 230]
# atom 220 is not at the interface.
# atom 221 neighbors: [ 214  213  218  219  222  223 1185  220  221 1184 1191  226  225  227
#   230  236 1194]
# atom 221 is not at the interface.
# atom 222 neighbors: [1177  213  218  219  222  224  223  220  221  225]
# atom 222 is not at the interface.
# atom 223 neighbors: [218 219 222 224 223 220 221 225]
# atom 223 is not at the interface.
# atom 224 neighbors: [ 166  160  165  161  164 1177  218  219  222  224  155  223  220]
# atom 224 is not at the interface.
# atom 225 neighbors: [214 213 218 219 222 223 220 221 226 229 225 227 228 230]
# atom 225 is not at the interface.
# atom 226 neighbors: [ 219 1196  220  221  226  229  225  227  228  230 1194  231]
# atom 226 is not at the interface.
# atom 227 neighbors: [ 220  221  226  229  225  227  228  230  236 1194  231  232  234]
# atom 227 is not at the interface.
# atom 228 neighbors: [220 226 229 225 227 228 230 463 468 471 231 232]
# atom 228 is not at the interface.
# atom 229 neighbors: [220 226 229 225 227 228 230]
# atom 229 is not at the interface.
# atom 230 neighbors: [ 220  221  226  229  225  227  228  230  236 1194  231  232  233  234
#   235  237]
# atom 230 is not at the interface.
# atom 231 neighbors: [ 226  227  228  230  236  463 1194  231  232  233  234  235  237  238]
# atom 231 is not at the interface.
# atom 232 neighbors: [ 227  228  230  236  463 1194  231  232  233  234  235  241  242  237
#   238  239  240]
# atom 232 is not at the interface.
# atom 233 neighbors: [ 230 1194 1198  231  232  233  234  235  237  238  239 1199 1204 1205
#  1207  243]
# atom 233 is not at the interface.
# atom 234 neighbors: [ 227  230  236 1194  231  232  233  234  235  237]
# atom 234 is not at the interface.
# atom 235 neighbors: [230 236 463 231 232 233 234 235 237 240 459]
# atom 235 is not at the interface.
# atom 236 neighbors: [221 227 230 236 231 232 234 235]
# atom 236 is not at the interface.
# atom 237 neighbors: [230 462 463 231 232 233 234 235 241 242 237 238 239 240 243]
# atom 237 is not at the interface.
# atom 238 neighbors: [ 463  231  232  233  241  242  237  238  239  240 1207  243  244]
# atom 238 is not at the interface.
# atom 239 neighbors: [ 232  233  241  242  237  238  239  240 1207  249  243  244  245  247]
# atom 239 is not at the interface.
# atom 240 neighbors: [463 461 232 235 241 237 238 239 240 460 459 454 455 249 243 244 245 247
#  447]
# atom 240 is not at the interface.
# atom 241 neighbors: [ 466  232  241  242  237  238  239  240  464 1207 1224  243]
# atom 241 is not at the interface.
# atom 242 neighbors: [ 466  232  241  242  237  238  239 1207 1224]
# atom 242 is not at the interface.
# atom 243 neighbors: [ 233  241  237  238  239  240 1207  249  243  244  245  246  247  250
#   248]
# atom 243 is not at the interface.
# atom 244 neighbors: [238 239 240 249 243 244 245 246 247 250 248 447 251]
# atom 244 is not at the interface.
# atom 245 neighbors: [239 240 249 243 244 245 246 247 250 248 447 251 252 254]
# atom 245 is not at the interface.
# atom 246 neighbors: [1207 1213 1219  243  244  245  246  247  250  248 1419  251  254]
# atom 246 is not at the interface.
# atom 247 neighbors: [239 240 249 243 244 245 246 247 250 248]
# atom 247 is not at the interface.
# atom 248 neighbors: [249 243 244 245 246 247 250 248]
# atom 248 is not at the interface.
# atom 249 neighbors: [697 239 240 249 243 244 245 247 248]
# atom 249 is not at the interface.
# atom 250 neighbors: [243 244 245 246 247 250 248 447 251 252 254 255 256 253]
# atom 250 is not at the interface.
# atom 251 neighbors: [244 245 246 250 251 252 254 255 256 253 257]
# atom 251 is not at the interface.
# atom 252 neighbors: [245 250 251 263 252 254 255 256 253 257 261 259 258 260]
# atom 252 is not at the interface.
# atom 253 neighbors: [250 437 444 445 447 448 251 263 252 254 255 256 253 257 424 436 258 264]
# atom 253 is not at the interface.
# atom 254 neighbors: [245 246 250 251 252 254 255 256 253]
# atom 254 is not at the interface.
# atom 255 neighbors: [ 250  251 1222  252  254  255  256  253  271  272]
# atom 255 is not at the interface.
# atom 256 neighbors: [ 250  251  263  252  254  255  256  253  257 1420  261  259  258  260
#   264]
# atom 256 is not at the interface.
# atom 257 neighbors: [251 263 252 256 253 257 424 261 262 259 258 260 264 265]
# atom 257 is not at the interface.
# atom 258 neighbors: [252 256 253 257 424 269 270 268 261 259 258 260 264 265 266 267 273]
# atom 258 is not at the interface.
# atom 259 neighbors: [252 256 257 270 268 259 258 260 264 265 266 273]
# atom 259 is not at the interface.
# atom 260 neighbors: [263 252 256 257 261 262 259 258 260 264]
# atom 260 is not at the interface.
# atom 261 neighbors: [263 252 256 257 261 262 258 260]
# atom 261 is not at the interface.
# atom 262 neighbors: [ 263  257 1569  261  262  260]
# atom 262 is not at the interface.
# atom 263 neighbors: [440 263 419 252 256 253 257 417 261 262 260]
# atom 263 is not at the interface.
# atom 264 neighbors: [256 253 257 424 269 270 268 259 258 260 264 265 266 267 273]
# atom 264 is not at the interface.
# atom 265 neighbors: [257 424 269 270 268 259 258 264 265 266 267 273 274]
# atom 265 is not at the interface.
# atom 266 neighbors: [269 268 421 259 258 264 265 266 267 273 277 274 275 276 284]
# atom 266 is not at the interface.
# atom 267 neighbors: [424 268 425 412 421 422 258 264 411 414 265 266 267 273 289 291 274 275
#  276 284]
# atom 267 is not at the interface.
# atom 268 neighbors: [ 269  270  271  268  259  258  264  265  266  267  273 1294]
# atom 268 is not at the interface.
# atom 269 neighbors: [269 270 271 272 268 258 264 265 266]
# atom 269 is not at the interface.
# atom 270 neighbors: [269 270 271 272 268 259 258 264 265]
# atom 270 is not at the interface.
# atom 271 neighbors: [ 451  255 1240  269  270  271  272  268]
# atom 271 is not at the interface.
# atom 272 neighbors: [ 255 1238 1239 1240  269  270  271  272]
# atom 272 is not at the interface.
# atom 273 neighbors: [268 259 258 264 265 266 267 273 277 278 279 280 274 275 276 284]
# atom 273 is not at the interface.
# atom 274 neighbors: [265 266 267 273 277 278 279 280 274 275 276 284 285 406]
# atom 274 is not at the interface.
# atom 275 neighbors: [266 267 273 289 288 291 277 278 274 275 276 284 285 286 292 406]
# atom 275 is not at the interface.
# atom 276 neighbors: [ 266  267  273  291  277  274  275  276  284  285  286 1289 1290 1299
#  1300 1303 1305]
# atom 276 is not at the interface.
# atom 277 neighbors: [ 266  273  277  278  279  280  281  282  274  275  276  284 1381]
# atom 277 is not at the interface.
# atom 278 neighbors: [273 283 277 278 279 280 281 282 274 275]
# atom 278 is not at the interface.
# atom 279 neighbors: [273 283 277 278 279 280 281 282 401 274]
# atom 279 is not at the interface.
# atom 280 neighbors: [273 283 277 278 279 280 281 282 274]
# atom 280 is not at the interface.
# atom 281 neighbors: [ 283  277  278  279  280  281  282  401 1583]
# atom 281 is not at the interface.
# atom 282 neighbors: [283 277 278 279 280 281 282]
# atom 282 is not at the interface.
# atom 283 neighbors: [283 278 279 280 281 282]
# atom 283 is not at the interface.
# atom 284 neighbors: [266 267 273 289 405 288 290 291 277 274 275 276 284 285 286 292 406 287]
# atom 284 is not at the interface.
# atom 285 neighbors: [ 289  288  290  291  274  275  276  284  285  286  292  293  406 1290
#   287]
# atom 285 is not at the interface.
# atom 286 neighbors: [ 289  288  290  275  276  284  285  286  292  293  406  296 1310  287
#  1305 1307  294]
# atom 286 is not at the interface.
# atom 287 neighbors: [ 288  290  284  285  286  292  293  296 1290 1300 1301 1310  287 1305
#  1307 1311 1314  297]
# atom 287 is not at the interface.
# atom 288 neighbors: [289 408 288 290 291 275 284 285 286 292 406 287]
# atom 288 is not at the interface.
# atom 289 neighbors: [427 429 411 267 289 288 290 291 275 284 285 286 406]
# atom 289 is not at the interface.
# atom 290 neighbors: [289 288 290 291 284 285 286 292 287]
# atom 290 is not at the interface.
# atom 291 neighbors: [ 427  429  430  267  289 1291  288  290  291  275  276  284  285 1290]
# atom 291 is not at the interface.
# atom 292 neighbors: [ 288  290  275  284  285  286  292  293  295  406  296  287 1305 1307
#   294  300  297]
# atom 292 is not at the interface.
# atom 293 neighbors: [ 285  286  292  293  295  296  287 1307  294  300  301  298  297  299]
# atom 293 is not at the interface.
# atom 294 neighbors: [ 403  286  292  293  295  296  304  305 1307  294  300  301  298  302
#   303  297]
# atom 294 is not at the interface.
# atom 295 neighbors: [404 401 397 398 403 292 293 295 406 296 304 305 294 300 301 302]
# atom 295 is not at the interface.
# atom 296 neighbors: [286 292 293 295 296 287 294 300 298 297 299]
# atom 296 is not at the interface.
# atom 297 neighbors: [ 292  293  296  287  294  300  298  315 1314  297  299]
# atom 297 is not at the interface.
# atom 298 neighbors: [ 293  296  294  300  301  298  302  303  315  297  299 1342 1338 1341]
# atom 298 is not at the interface.
# atom 299 neighbors: [ 293  296  298  315 1314  297  299 1315 7492 7493]
# atom 299 is at the interface.
# atom 300 neighbors: [ 292  293  295  296  304  305  306  308 1307 1309  294  300  301  298
#   302  303  297 1342]
# atom 300 is not at the interface.
# atom 301 neighbors: [293 295 304 305 306 307 308 391 294 300 301 298 302 303 309]
# atom 301 is not at the interface.
# atom 302 neighbors: [295 304 305 306 308 391 294 300 301 298 302 303 309 313 312 310]
# atom 302 is not at the interface.
# atom 303 neighbors: [ 304  306  308  294  300  301  298  302  303  309  312  310 1342 1360]
# atom 303 is not at the interface.
# atom 304 neighbors: [295 304 305 306 307 308 294 300 301 302 303]
# atom 304 is not at the interface.
# atom 305 neighbors: [ 295  304  305  306  307 1307 1309  294  300  301  302]
# atom 305 is not at the interface.
# atom 306 neighbors: [ 304  305  306  307  308  300  301  302  303  331 1360]
# atom 306 is not at the interface.
# atom 307 neighbors: [1583  304  305  306  307 1309  301 1596 1597 1599]
# atom 307 is not at the interface.
# atom 308 neighbors: [304 306 308 391 300 301 302 303 309 313 315 312 310 316 311]
# atom 308 is not at the interface.
# atom 309 neighbors: [314 308 391 301 302 303 309 313 315 312 310 316 317 311]
# atom 309 is not at the interface.
# atom 310 neighbors: [308 302 303 309 313 312 325 310 316 317 318 320 311]
# atom 310 is not at the interface.
# atom 311 neighbors: [308 309 312 310 316 317 320 311]
# atom 311 is not at the interface.
# atom 312 neighbors: [314 308 391 392 302 303 309 313 315 312 310 316 311]
# atom 312 is not at the interface.
# atom 313 neighbors: [314 308 302 309 313 315 312 310]
# atom 313 is not at the interface.
# atom 314 neighbors: [939 409 314 938 940 941 942 309 313 315 312]
# atom 314 is not at the interface.
# atom 315 neighbors: [ 314  308  298  309  313  315  312  297  299 6894]
# atom 315 is at the interface.
# atom 316 neighbors: [308 392 309 312 319 325 310 316 317 318 320 321 311]
# atom 316 is not at the interface.
# atom 317 neighbors: [309 326 319 325 310 316 317 318 320 321 322 311]
# atom 317 is not at the interface.
# atom 318 neighbors: [326 329 319 325 310 316 317 318 320 321 327 328]
# atom 318 is not at the interface.
# atom 319 neighbors: [388 960 961 375 326 319 962 325 316 317 318 320 321 327 332 328]
# atom 319 is not at the interface.
# atom 320 neighbors: [319 325 310 316 317 318 320 321 322 323 324 311]
# atom 320 is not at the interface.
# atom 321 neighbors: [319 316 317 318 320 321 322 323 324]
# atom 321 is not at the interface.
# atom 322 neighbors: [317 320 321 322 323 324]
# atom 322 is not at the interface.
# atom 323 neighbors: [320 321 322 323 324]
# atom 323 is not at the interface.
# atom 324 neighbors: [320 321 322 323 324]
# atom 324 is not at the interface.
# atom 325 neighbors: [326 329 319 325 331 310 316 317 318 320 327 330 332 328]
# atom 325 is not at the interface.
# atom 326 neighbors: [375 326 329 319 325 331 317 318 327 330 332 328 333]
# atom 326 is not at the interface.
# atom 327 neighbors: [375 326 329 319 325 331 318 334 336 327 330 332 328 333]
# atom 327 is not at the interface.
# atom 328 neighbors: [326 329 319 325 318 336 327 330 332 328 333]
# atom 328 is not at the interface.
# atom 329 neighbors: [ 326  329  325  331  318  327  330  332  328 1363 1364]
# atom 329 is not at the interface.
# atom 330 neighbors: [326 329 325 331 999 327 330 332 328]
# atom 330 is not at the interface.
# atom 331 neighbors: [ 306 1601  326  329  386  325  331 1362  327  330 1363 1364]
# atom 331 is not at the interface.
# atom 332 neighbors: [375 326 329 319 325 334 335 340 336 337 327 330 332 328 333]
# atom 332 is not at the interface.
# atom 333 neighbors: [375 326 334 335 340 341 336 337 338 339 327 332 328 333]
# atom 333 is not at the interface.
# atom 334 neighbors: [334 335 340 341 342 349 336 337 338 327 332 333 344]
# atom 334 is not at the interface.
# atom 335 neighbors: [364 365 359 366 372 375 362 343 357 334 335 340 341 342 349 336 337 338
#  332 333]
# atom 335 is not at the interface.
# atom 336 neighbors: [375 362 334 335 340 336 337 338 339 327 332 328 333]
# atom 336 is not at the interface.
# atom 337 neighbors: [362 357 363 334 335 340 336 337 338 339 332 333]
# atom 337 is not at the interface.
# atom 338 neighbors: [362 351 357 363 334 335 340 342 349 336 337 338 339 333 350 353 354]
# atom 338 is not at the interface.
# atom 339 neighbors: [362 363 336 337 338 339 333]
# atom 339 is not at the interface.
# atom 340 neighbors: [343 334 335 340 341 342 349 336 337 338 332 333 344 345]
# atom 340 is not at the interface.
# atom 341 neighbors: [343 999 334 335 340 341 342 349 333 350 346 344 345]
# atom 341 is not at the interface.
# atom 342 neighbors: [343 351 352 357 334 335 340 341 342 349 338 350 344 345 353]
# atom 342 is not at the interface.
# atom 343 neighbors: [364 343 351 352 357 335 340 341 342 349 350 344 345]
# atom 343 is not at the interface.
# atom 344 neighbors: [343 334 340 341 342 349 346 347 348 344 345]
# atom 344 is not at the interface.
# atom 345 neighbors: [343 340 341 342 346 347 348 344 345]
# atom 345 is not at the interface.
# atom 346 neighbors: [341 346 347 348 344 345]
# atom 346 is not at the interface.
# atom 347 neighbors: [1016  346  347  348  344  345]
# atom 347 is not at the interface.
# atom 348 neighbors: [1003 1002 1007  346  347  348  344  345]
# atom 348 is not at the interface.
# atom 349 neighbors: [343 351 352 357 334 335 340 341 342 349 338 350 355 344 353 354 356]
# atom 349 is not at the interface.
# atom 350 neighbors: [343 351 352 357 358 341 342 349 338 350 355 353 354 356]
# atom 350 is not at the interface.
# atom 351 neighbors: [364 359 361 343 351 352 357 358 363 342 349 338 350 355 353 354]
# atom 351 is not at the interface.
# atom 352 neighbors: [ 364  359 2980 2981  343  351  352  357  358  342  349  350  355  353]
# atom 352 is at the interface.
# atom 353 neighbors: [351 352 357 342 349 338 350 355 353 354 356]
# atom 353 is not at the interface.
# atom 354 neighbors: [351 349 338 350 355 353 354 356]
# atom 354 is not at the interface.
# atom 355 neighbors: [ 351  352  357  349 2984  350  355  353  354  356]
# atom 355 is at the interface.
# atom 356 neighbors: [349 350 355 353 354 356]
# atom 356 is not at the interface.
# atom 357 neighbors: [364 359 360 361 362 343 351 352 357 358 363 335 342 349 337 338 350 355
#  353]
# atom 357 is not at the interface.
# atom 358 neighbors: [364 365 359 360 361 362 351 352 357 358 363 350]
# atom 358 is not at the interface.
# atom 359 neighbors: [364 365 367 368 359 360 361 366 372 362 351 352 357 358 363 335]
# atom 359 is not at the interface.
# atom 360 neighbors: [364 365 367 368 359 360 361 366 372 362 377 357 358]
# atom 360 is not at the interface.
# atom 361 neighbors: [364 359 360 361 380 362 378 351 357 358 363]
# atom 361 is not at the interface.
# atom 362 neighbors: [379 364 359 360 361 380 372 362 376 377 378 357 358 363 335 336 337 338
#  339]
# atom 362 is not at the interface.
# atom 363 neighbors: [359 361 362 351 357 358 363 337 338 339]
# atom 363 is not at the interface.
# atom 364 neighbors: [364 365 367 368 369 359 360 361 366 372 362 370 343 351 352 357 358 335]
# atom 364 is not at the interface.
# atom 365 neighbors: [ 983  364  365  367  368  369  359  360 1000  366  372  373  370  371
#   358  335]
# atom 365 is not at the interface.
# atom 366 neighbors: [ 983  364  365  367  368  369  359  360 1000  366  372  373  374  375
#   376  377  335]
# atom 366 is not at the interface.
# atom 367 neighbors: [975 976 980 966 983 364 365 367 368 359 360 366 372 373 374 376 377]
# atom 367 is not at the interface.
# atom 368 neighbors: [2960  983  364  365  367  368  369  359  360  366  372  370  371]
# atom 368 is at the interface.
# atom 369 neighbors: [2960  983  364  365  368  369  994  366  370  371]
# atom 369 is at the interface.
# atom 370 neighbors: [ 983  987  364  365  368  369  988  994 1000  370  371  995  998 1001]
# atom 370 is not at the interface.
# atom 371 neighbors: [2961 2960  365  368  369  370  371]
# atom 371 is at the interface.
# atom 372 neighbors: [ 381  364  365  367  368  359  360 1000  366  372  373  374  375  362
#   376  377  335]
# atom 372 is not at the interface.
# atom 373 neighbors: [381 966 382 365 367 366 372 373 374 375 376 377 378]
# atom 373 is not at the interface.
# atom 374 neighbors: [381 966 382 383 385 367 366 372 373 374 375 376 377 386]
# atom 374 is not at the interface.
# atom 375 neighbors: [381 382 385 366 372 373 374 375 376 326 386 319 335 336 327 332 333]
# atom 375 is not at the interface.
# atom 376 neighbors: [381 966 379 959 960 367 380 366 372 373 374 375 362 376 377 378 962]
# atom 376 is not at the interface.
# atom 377 neighbors: [379 741 367 360 380 366 372 373 374 362 376 377 378]
# atom 377 is not at the interface.
# atom 378 neighbors: [379 741 361 380 373 362 376 377 378]
# atom 378 is not at the interface.
# atom 379 neighbors: [379 741 959 960 380 362 376 377 378 962]
# atom 379 is not at the interface.
# atom 380 neighbors: [1985  379  361  380  362  376  377  378]
# atom 380 is at the interface.
# atom 381 neighbors: [381 966 382 383 384 385 387 388 372 373 374 375 376 386]
# atom 381 is not at the interface.
# atom 382 neighbors: [381 382 383 384 385 387 388 389 373 374 375 386]
# atom 382 is not at the interface.
# atom 383 neighbors: [394 381 382 383 384 385 387 388 389 961 390 391 392 374 386]
# atom 383 is not at the interface.
# atom 384 neighbors: [963 964 954 946 394 953 956 381 966 382 383 384 385 387 388 389 957 390]
# atom 384 is not at the interface.
# atom 385 neighbors: [381 382 383 384 385 387 388 374 375 386]
# atom 385 is not at the interface.
# atom 386 neighbors: [ 381  382  383  385  387 1000  374  375  386  331]
# atom 386 is not at the interface.
# atom 387 neighbors: [402 985 381 382 383 384 385 387 388 386]
# atom 387 is not at the interface.
# atom 388 neighbors: [394 396 381 382 383 384 385 387 388 389 961 390 391 392 393 319]
# atom 388 is not at the interface.
# atom 389 neighbors: [946 394 396 397 382 383 384 388 389 390 391 392 393 395]
# atom 389 is not at the interface.
# atom 390 neighbors: [402 946 400 396 397 398 399 383 384 388 389 390 391 392 393]
# atom 390 is not at the interface.
# atom 391 neighbors: [402 400 396 397 398 383 388 389 308 390 391 392 301 302 309 312]
# atom 391 is not at the interface.
# atom 392 neighbors: [394 396 383 388 389 961 390 391 392 393 395 312 316]
# atom 392 is not at the interface.
# atom 393 neighbors: [394 939 388 389 961 390 392 393 395 942]
# atom 393 is not at the interface.
# atom 394 neighbors: [946 394 952 953 956 383 384 388 389 957 958 961 392 393 395]
# atom 394 is not at the interface.
# atom 395 neighbors: [394 939 940 389 392 393 395 942]
# atom 395 is not at the interface.
# atom 396 neighbors: [402 946 400 401 396 397 398 399 403 388 389 390 391 392]
# atom 396 is not at the interface.
# atom 397 neighbors: [404 402 946 400 401 396 397 398 399 403 295 389 390 391]
# atom 397 is not at the interface.
# atom 398 neighbors: [405 404 402 400 401 396 397 398 399 403 295 406 407 409 390 391]
# atom 398 is not at the interface.
# atom 399 neighbors: [927 933 934 943 405 404 946 400 401 396 397 398 399 403 937 407 409 390]
# atom 399 is not at the interface.
# atom 400 neighbors: [402 400 401 396 397 398 399 403 390 391]
# atom 400 is not at the interface.
# atom 401 neighbors: [416 405 402 279 281 400 401 396 397 398 399 403 295 406]
# atom 401 is not at the interface.
# atom 402 neighbors: [402 400 401 396 397 398 387 390 391]
# atom 402 is not at the interface.
# atom 403 neighbors: [410 405 404 408 400 401 396 397 398 399 403 295 406 407 409 294]
# atom 403 is not at the interface.
# atom 404 neighbors: [410 411 927 405 404 408 397 398 399 403 295 406 407 409]
# atom 404 is not at the interface.
# atom 405 neighbors: [412 410 411 414 415 416 927 405 404 408 401 398 399 403 284 406 407 409]
# atom 405 is not at the interface.
# atom 406 neighbors: [410 411 414 289 405 404 408 288 401 398 403 274 275 284 285 286 292 295
#  406 407]
# atom 406 is not at the interface.
# atom 407 neighbors: [410 927 405 404 408 398 399 403 406 407 409]
# atom 407 is not at the interface.
# atom 408 neighbors: [923 410 927 405 404 408 786 288 403 406 407 409]
# atom 408 is not at the interface.
# atom 409 neighbors: [405 404 408 398 399 403 407 409 314]
# atom 409 is not at the interface.
# atom 410 neighbors: [413 417 412 421 410 411 414 415 416 927 405 404 408 403 406 407]
# atom 410 is not at the interface.
# atom 411 neighbors: [413 417 412 421 422 410 411 414 415 416 267 289 405 404 406]
# atom 411 is not at the interface.
# atom 412 neighbors: [424 413 417 423 435 425 412 421 422 427 924 410 411 414 415 267 405]
# atom 412 is not at the interface.
# atom 413 neighbors: [914 413 417 423 435 925 928 412 421 422 919 920 923 924 410 411 414 415
#  927]
# atom 413 is not at the interface.
# atom 414 neighbors: [419 413 417 412 421 418 410 411 414 415 416 267 405 406]
# atom 414 is not at the interface.
# atom 415 neighbors: [419 413 417 412 421 418 420 410 411 414 415 416 405]
# atom 415 is not at the interface.
# atom 416 neighbors: [419 417 418 420 410 411 414 415 416 927 405 401]
# atom 416 is not at the interface.
# atom 417 neighbors: [263 419 424 413 417 423 412 418 420 410 411 414 415 416]
# atom 417 is not at the interface.
# atom 418 neighbors: [419 417 418 420 973 414 415 416 927 972]
# atom 418 is not at the interface.
# atom 419 neighbors: [263 419 442 417 418 420 414 415 416]
# atom 419 is not at the interface.
# atom 420 neighbors: [419 417 930 418 420 950 415 416]
# atom 420 is not at the interface.
# atom 421 neighbors: [424 413 423 435 425 412 421 422 426 427 410 411 414 415 266 267]
# atom 421 is not at the interface.
# atom 422 neighbors: [914 424 413 423 435 436 425 412 421 422 426 427 428 411 267]
# atom 422 is not at the interface.
# atom 423 neighbors: [437 444 439 914 424 413 417 423 435 436 425 412 421 422 426]
# atom 423 is not at the interface.
# atom 424 neighbors: [437 444 253 257 424 417 423 435 436 425 412 421 422 258 264 265 267]
# atom 424 is not at the interface.
# atom 425 neighbors: [908 424 423 435 425 412 421 422 426 427 428 431 429 430 267]
# atom 425 is not at the interface.
# atom 426 neighbors: [423 425 421 422 426 427 428 431 433 429 430 432]
# atom 426 is not at the interface.
# atom 427 neighbors: [425 412 421 422 426 427 919 922 923 428 431 429 430 432 289 291]
# atom 427 is not at the interface.
# atom 428 neighbors: [425 422 426 427 428 431 433 434 429 430 432]
# atom 428 is not at the interface.
# atom 429 neighbors: [7641  425  426  427  922  923  428  431  434  429  430  432 7643  289
#   291]
# atom 429 is at the interface.
# atom 430 neighbors: [7641  425  426  427  428  431  433  434  429  430  432 7643  291]
# atom 430 is at the interface.
# atom 431 neighbors: [909 910 425 426 427 428 431 433 434 429 430 432]
# atom 431 is not at the interface.
# atom 432 neighbors: [ 426  427  428  431  433  434  429  430  432 7643]
# atom 432 is at the interface.
# atom 433 neighbors: [426 428 431 433 434 430 432]
# atom 433 is not at the interface.
# atom 434 neighbors: [428 431 433 434 429 430 432]
# atom 434 is not at the interface.
# atom 435 neighbors: [440 437 444 438 439 914 424 413 423 435 436 425 412 421 422]
# atom 435 is not at the interface.
# atom 436 neighbors: [440 441 437 444 445 438 439 253 424 423 435 436 422]
# atom 436 is not at the interface.
# atom 437 neighbors: [458 453 440 437 444 445 446 447 448 438 439 253 424 423 435 436]
# atom 437 is not at the interface.
# atom 438 neighbors: [458 453 894 440 437 444 445 446 447 438 439 917 904 435 436]
# atom 438 is not at the interface.
# atom 439 neighbors: [440 441 443 437 444 438 439 442 423 435 436]
# atom 439 is not at the interface.
# atom 440 neighbors: [458 440 441 443 437 438 439 263 442 435 436]
# atom 440 is not at the interface.
# atom 441 neighbors: [440 441 443 439 442 436]
# atom 441 is not at the interface.
# atom 442 neighbors: [440 441 443 439 419 442 931]
# atom 442 is not at the interface.
# atom 443 neighbors: [458 440 441 443 439 442]
# atom 443 is not at the interface.
# atom 444 neighbors: [453 449 437 444 445 446 447 448 438 439 908 253 424 423 435 436]
# atom 444 is not at the interface.
# atom 445 neighbors: [453 454 894 449 437 444 445 446 447 448 438 450 908 253 436]
# atom 445 is not at the interface.
# atom 446 neighbors: [457 458 453 454 455 894 449 437 444 445 446 447 448 438]
# atom 446 is not at the interface.
# atom 447 neighbors: [240 457 458 453 454 455 244 245 250 449 437 444 445 446 447 448 438 253]
# atom 447 is not at the interface.
# atom 448 neighbors: [453 449 452 437 444 445 446 447 448 450 451 909 253]
# atom 448 is not at the interface.
# ...
# atom 7989 neighbors: [7992 7998 7999 7983 7984 7987 7988 7991 7993 7989 7990 7994 7995 7996
#  7997]
# atom 7989 is not at the interface.
# atom 7990 neighbors: [7984 7987 7988 7991 7989 7990 7994 7995 7996 7997]
# atom 7990 is not at the interface.
# atom 7991 neighbors: [7992 7983 7987 7988 7991 7993 7989 7990 7994]
# atom 7991 is not at the interface.
# atom 7992 neighbors: [7992 7983 7987 7988 7991 7993 7989 7994]
# atom 7992 is not at the interface.
# atom 7993 neighbors: [7992 7982 7983 7984 7987 7988 7991 7993 7985 7989 7994]
# atom 7993 is not at the interface.
# atom 7994 neighbors: [7992 7998 7999 7983 7984 7987 7988 7991 7993 7989 7990 7994 7995 7996
#  7997 8003]
# atom 7994 is not at the interface.
# atom 7995 neighbors: [7998 7999 8000 8001 7988 7989 7990 7994 7995 7996 7997 8003 8004]
# atom 7995 is not at the interface.
# atom 7996 neighbors: [7998 7999 8016 7989 7990 7994 7995 7996 7997 8003 8004 8005 8006 8007]
# atom 7996 is not at the interface.
# atom 7997 neighbors: [7998 7984 8016 7989 7990 7994 7995 7996 7997 8003 8004 8005 8014 7955
#  7956 7951]
# atom 7997 is not at the interface.
# atom 7998 neighbors: [8002 7998 7999 8000 8001 7665 7666 7989 7994 7995 7996 7997 8003]
# atom 7998 is not at the interface.
# atom 7999 neighbors: [8002 7998 7999 8000 8001 7668 7989 7994 7995 7996]
# atom 7999 is not at the interface.
# atom 8000 neighbors: [7687 8002 7998 7999 8000 8001 7995]
# atom 8000 is not at the interface.
# atom 8001 neighbors: [7684 8002 7998 7999 8000 8001 7995]
# atom 8001 is not at the interface.
# atom 8002 neighbors: [7687 7684 7685 8002 7998 7999 8000 8001]
# atom 8002 is not at the interface.
# atom 8003 neighbors: [7998 7994 7995 7996 7997 8003 8004 8005 8006 8008 8007]
# atom 8003 is not at the interface.
# atom 8004 neighbors: [7995 7996 7997 8003 8004 8005 8006 8008 8009 8007 7946]
# atom 8004 is not at the interface.
# atom 8005 neighbors: [7996 7997 8003 8004 8005 8006 8008 8009 8013 8014 8007 7946 8012 8010]
# atom 8005 is not at the interface.
# atom 8006 neighbors: [7662 7663 7665 7676 7671 7672 7996 8003 8004 8005 8006 8008 8009 8013
#  8014 8007 7675 8012 8010]
# atom 8006 is not at the interface.
# atom 8007 neighbors: [7996 8003 8004 8005 8006 8008 8007 7955 7946 7942]
# atom 8007 is not at the interface.
# atom 8008 neighbors: [8003 8004 8005 8006 8008 8009 8013 8014 8007 7945 7946 8012 7943 8010
#  8011 8020]
# atom 8008 is not at the interface.
# atom 8009 neighbors: [8004 8005 8006 8008 8009 8013 8014 8015 7946 8012 8010 8011 8020 8021]
# atom 8009 is not at the interface.
# atom 8010 neighbors: [8005 8006 8008 8009 8013 8024 8025 8012 7943 8010 8011 8020 8021 8022
#  8023]
# atom 8010 is not at the interface.
# atom 8011 neighbors: [8008 8009 7946 8012 7939 7943 7938 8010 8011 8020 8021 8022 8023 8029
#  7932 7947 7944]
# atom 8011 is not at the interface.
# atom 8012 neighbors: [8016 8017 8005 8006 8008 8009 8013 8014 8015 7946 7965 8012 8010 8011
#  8020]
# atom 8012 is not at the interface.
# atom 8013 neighbors: [8016 8017 8018 8005 8006 8008 8009 8013 8014 8015 8012 8010]
# atom 8013 is not at the interface.
# atom 8014 neighbors: [8016 8017 8018 8019 7997 8005 8006 8008 8009 8013 8014 8015 8012]
# atom 8014 is not at the interface.
# atom 8015 neighbors: [7661 7662 7653 8016 8017 8018 8019 8009 8013 8014 8015 7654 8012]
# atom 8015 is not at the interface.
# atom 8016 neighbors: [8016 8017 8018 8019 7996 7997 8013 8014 8015 8012]
# atom 8016 is not at the interface.
# atom 8017 neighbors: [7646 7661 7662 7665 7653 8016 8017 8018 8019 8013 8014 8015 7654 8012]
# atom 8017 is not at the interface.
# atom 8018 neighbors: [7665 8016 8017 8018 8019 8013 8014 8015]
# atom 8018 is not at the interface.
# atom 8019 neighbors: [8016 8017 8018 8019 8014 8015]
# atom 8019 is not at the interface.
# atom 8020 neighbors: [8008 8009 8024 8025 8012 8010 8011 8020 8021 8022 8023 8029]
# atom 8020 is not at the interface.
# atom 8021 neighbors: [8009 8024 8025 8026 8010 8011 8020 8021 8022 8023 8029 8030 7932]
# atom 8021 is not at the interface.
# atom 8022 neighbors: [8024 8025 8010 8011 8020 8021 8022 8023 8029 8030 7717 7932 8031 8033
#  8032]
# atom 8022 is not at the interface.
# atom 8023 neighbors: [8024 7621 8010 8011 8020 8021 8022 8023 8029 8030 7717 8033]
# atom 8023 is not at the interface.
# atom 8024 neighbors: [8024 8025 8026 8028 8027 8010 8020 8021 8022 8023 8029 7717 7932]
# atom 8024 is not at the interface.
# atom 8025 neighbors: [7675 8024 8025 8026 8028 8027 8010 8020 8021 8022]
# atom 8025 is not at the interface.
# atom 8026 neighbors: [7706 7709 8024 8025 8026 8028 8027 7928 8021 7927]
# atom 8026 is not at the interface.
# atom 8027 neighbors: [7706 7709 8024 8025 8026 8028 7707 7711 8027 7928 7714 7927]
# atom 8027 is not at the interface.
# atom 8028 neighbors: [7675 8024 8025 8026 8028 8027 7928 7927]
# atom 8028 is not at the interface.
# atom 8029 neighbors: [8024 8011 8020 8021 8022 8023 8029 8030 7717 7932 8031 8033 8034 8035
#  8036 8037 8032]
# atom 8029 is not at the interface.
# atom 8030 neighbors: [8021 8022 8023 8029 8030 7615 7717 8031 8033 8034 8035 8036 8037 8032
#  8038]
# atom 8030 is not at the interface.
# atom 8031 neighbors: [8022 8029 8030 7615 7717 8043 8031 8033 8034 8035 8037 8039 8040 8032
#  8038 8041]
# atom 8031 is not at the interface.
# atom 8032 neighbors: [8022 8029 8030 7932 7925 8043 8031 8033 8034 8035 8037 8039 7930 7914
#  7921 7922 7929 8032 8038 8041]
# atom 8032 is not at the interface.
# atom 8033 neighbors: [7614 8022 8023 8029 8030 7615 8031 8033 8034 8035 8036 8037 8032]
# atom 8033 is not at the interface.
# atom 8034 neighbors: [8029 8030 7610 8031 8033 8034 8035 8036 8037 7933 8032 7608]
# atom 8034 is not at the interface.
# atom 8035 neighbors: [8029 8030 8031 8033 8034 8035 8036 8037 8039 8040 7933 7934 7929 8032
#  8038 8044 8049 7936]
# atom 8035 is not at the interface.
# atom 8036 neighbors: [8029 8030 7610 7611 7949 8033 8034 8035 8036 7933 7609]
# atom 8036 is not at the interface.
# atom 8037 neighbors: [7614 8029 8030 7615 7717 8043 8031 8033 8034 8035 8037 8039 8040 8032
#  8038 8041 8042 8044]
# atom 8037 is not at the interface.
# atom 8038 neighbors: [8030 7615 8043 8031 8035 8037 8039 8040 7914 8032 8038 8041 8042 8044
#  8045]
# atom 8038 is not at the interface.
# atom 8039 neighbors: [8043 8031 8035 8037 8039 8040 7914 8032 8038 8041 8042 8044 8045 8046
#  8047 8048]
# atom 8039 is not at the interface.
# atom 8040 neighbors: [7615 7605 7612 7613 8031 8035 8037 8039 8040 8038 8041 8042 8044 7604
#  7598 8045 8046 8048]
# atom 8040 is not at the interface.
# atom 8041 neighbors: [8043 8031 8037 8039 8040 8032 8038 8041 8042 8044]
# atom 8041 is not at the interface.
# atom 8042 neighbors: [8043 8037 8039 8040 7914 8038 8041 8042 8044]
# atom 8042 is not at the interface.
# atom 8043 neighbors: [8043 7720 7726 8031 8037 8039 8032 8038 8041 8042]
# atom 8043 is not at the interface.
# atom 8044 neighbors: [8035 8037 8039 8040 7914 8038 8041 8042 8044 7913 8049 8045 8046 8047
#  8048 8053]
# atom 8044 is not at the interface.
# atom 8045 neighbors: [8039 8040 7914 8038 8044 8049 8050 7598 8045 8046 8047 8048 8053 8054]
# atom 8045 is not at the interface.
# atom 8046 neighbors: [8039 8040 8044 8049 7598 8045 8046 8047 8048 8053 8054 8057 8059 8056
#  8055 8060]
# atom 8046 is not at the interface.
# atom 8047 neighbors: [8039 7914 8044 8045 8046 8047 8048 8053 8054 7912 7915 7903 7904 7911
#  7898 8055 8060]
# atom 8047 is not at the interface.
# atom 8048 neighbors: [8039 8040 7914 8044 8049 8050 8051 8052 7936 8045 8046 8047 8048 8053]
# atom 8048 is not at the interface.
# atom 8049 neighbors: [8035 8044 8049 8050 8051 8052 7936 8045 8046 8048]
# atom 8049 is not at the interface.
# atom 8050 neighbors: [8049 8050 8051 8052 7936 8045 8048]
# atom 8050 is not at the interface.
# atom 8051 neighbors: [8049 8050 8051 8052 7936 8048]
# atom 8051 is not at the interface.
# atom 8052 neighbors: [8049 8050 8051 8052 7936 8048]
# atom 8052 is not at the interface.
# atom 8053 neighbors: [8044 7598 8045 8046 8047 8048 8053 8054 8057 8058 8059 8056 8055 8060]
# atom 8053 is not at the interface.
# atom 8054 neighbors: [7598 8045 8046 8047 8053 8054 8057 8058 8059 7898 8056 8055 8060 8061]
# atom 8054 is not at the interface.
# atom 8055 neighbors: [8046 8047 8053 8054 8057 8058 8059 7898 8056 8064 8065 8055 8060 8061
#  8062 8066]
# atom 8055 is not at the interface.
# atom 8056 neighbors: [7598 7596 8046 8053 8054 8057 8058 7585 7586 7581 7595 8056 8055 8060
#  8061 8062 8066]
# atom 8056 is not at the interface.
# atom 8057 neighbors: [8046 8053 8054 8057 8058 8059 8056 8055 8060]
# atom 8057 is not at the interface.
# atom 8058 neighbors: [7910 8053 8054 8057 8058 8059 8056 8055 8060 7893]
# atom 8058 is not at the interface.
# atom 8059 neighbors: [7910 8046 8053 8054 8057 8058 8059 8055]
# atom 8059 is not at the interface.
# atom 8060 neighbors: [8046 8047 8053 8054 8057 8058 7897 7898 8056 8064 8065 8055 8060 8061
#  8062 8063 8066]
# atom 8060 is not at the interface.
# atom 8061 neighbors: [8054 7898 7581 8056 8064 8065 8055 8060 8061 8062 8063 8066 8067]
# atom 8061 is not at the interface.
# atom 8062 neighbors: [7581 8056 8064 8065 8055 8060 8061 8062 8063 8066 8070 8067 8068 8074]
# atom 8062 is not at the interface.
# atom 8063 neighbors: [7898 8064 8060 8061 8062 8063 8066 7890 7895 7889 7893 8067 8068 8074
#  7883]
# atom 8063 is not at the interface.
# atom 8064 neighbors: [7898 8064 8065 8055 8060 8061 8062 8063 8066 7900]
# atom 8064 is not at the interface.
# atom 8065 neighbors: [7590 7589 8064 8065 8055 8060 8061 8062]
# atom 8065 is not at the interface.
# atom 8066 neighbors: [7581 8056 8064 8055 8060 8061 8062 8063 8066 8070 7580 8067 8068 8069
#  8074 8071]
# atom 8066 is not at the interface.
# atom 8067 neighbors: [7581 8073 8061 8062 8063 8066 8070 8067 8068 8069 8074 8075 8071 8072
#  7883]
# atom 8067 is not at the interface.
# atom 8068 neighbors: [8062 8063 8066 8070 8067 8068 8069 8074 8075 8071 8072 8078 7883 8077
#  8076 8082]
# atom 8068 is not at the interface.
# atom 8069 neighbors: [7581 8066 8070 7573 7578 7579 8067 8068 8069 8074 8075 8071 8088 7569
#  7572 8076 8082]
# atom 8069 is not at the interface.
# atom 8070 neighbors: [7581 8073 8062 8066 8070 8067 8068 8069 8074 8071 8072]
# atom 8070 is not at the interface.
# atom 8071 neighbors: [8073 8066 8070 8067 8068 8069 8074 8071 8072]
# atom 8071 is not at the interface.
# atom 8072 neighbors: [8073 8070 7871 7894 8067 8068 8074 8071 8072 7869 7870]
# atom 8072 is not at the interface.
# atom 8073 neighbors: [6795 8073 6793 8070 8067 8071 8072]
# atom 8073 is not at the interface.
# atom 8074 neighbors: [8062 8063 8066 8070 8067 8068 8069 8074 8075 8071 8072 8078 7883 8077
#  8076 8082 8079]
# atom 8074 is not at the interface.
# atom 8075 neighbors: [8067 8068 8069 8074 8075 8078 7883 8077 7569 8081 8076 8082 8083 8079
#  8080]
# atom 8075 is not at the interface.
# atom 8076 neighbors: [8068 8069 8074 8075 8078 7883 8077 7569 8081 8076 8082 8083 8084 8085
#  8086 8079 8080 7872]
# atom 8076 is not at the interface.
# atom 8077 neighbors: [8068 8074 8075 8078 7874 7880 7883 8077 7865 7866 7870 8081 8076 8082
#  8083 8086 8079 7873 7876 7877 7872]
# atom 8077 is not at the interface.
# atom 8078 neighbors: [8068 8074 8075 8078 7880 7883 8077 7576 8081 8076 8082 8079 8080]
# atom 8078 is not at the interface.
# atom 8079 neighbors: [8074 8075 8078 8077 7569 7576 8081 8076 8082 8079 8080 7876 7559]
# atom 8079 is not at the interface.
# atom 8080 neighbors: [8075 8078 8081 8076 8079 8080 7876 7559 7878]
# atom 8080 is not at the interface.
# atom 8081 neighbors: [8075 8078 8077 7568 7569 7576 8081 8076 8082 8079 8080 7564 7559]
# atom 8081 is not at the interface.
# atom 8082 neighbors: [8068 8069 8074 8075 8078 8077 8087 8088 7569 8081 8076 8082 8083 8084
#  8085 8086 8093 8079]
# atom 8082 is not at the interface.
# atom 8083 neighbors: [8075 8077 8087 8088 8089 8076 8082 8083 8084 8085 8086 7858 8093 8094]
# atom 8083 is not at the interface.
# atom 8084 neighbors: [8087 8088 8089 8076 8082 8083 8084 8085 8086 7858 8093 8094 8095 8097]
# atom 8084 is not at the interface.
# atom 8085 neighbors: [7567 8087 8088 8089 7568 7569 8076 8082 8083 8084 8085 8086 8093 7564
#  7566 7563 8094 8097]
# atom 8085 is not at the interface.
# atom 8086 neighbors: [6821 8077 8087 8088 8089 8090 8091 8076 8082 8083 8084 8085 8086 7858
#  8093]
# atom 8086 is not at the interface.
# atom 8087 neighbors: [6821 8087 8088 8089 8090 8091 8092 8082 8083 8084 8085 8086 8093]
# atom 8087 is not at the interface.
# atom 8088 neighbors: [8069 8087 8088 8089 8090 8091 8092 7569 8082 8083 8084 8085 8086]
# atom 8088 is not at the interface.
# atom 8089 neighbors: [6821 8087 8088 8089 8090 8091 8092 8083 8084 8085 8086 8093]
# atom 8089 is not at the interface.
# atom 8090 neighbors: [7582 8087 8088 8089 8090 8091 8092 8086]
# atom 8090 is not at the interface.
# atom 8091 neighbors: [6845 8087 8088 8089 8090 8091 8092 8086 7531]
# atom 8091 is not at the interface.
# atom 8092 neighbors: [8087 8088 8089 8090 8091 8092]
# atom 8092 is not at the interface.
# atom 8093 neighbors: [8087 8089 8082 8083 8084 8085 8086 7858 8093 8104 8094 8095 8096 8097
#  8098]
# atom 8093 is not at the interface.
# atom 8094 neighbors: [8083 8084 8085 8093 7528 8104 8105 8094 8095 8096 8097 8098 8099]
# atom 8094 is not at the interface.
# atom 8095 neighbors: [7851 8084 8093 7528 8104 8105 8108 8094 8095 8096 8097 8098 8107 8106
#  8113]
# atom 8095 is not at the interface.
# atom 8096 neighbors: [7851 7845 7848 7858 8093 7846 7855 7856 7860 8104 8105 8094 8095 8096
#  8097 8098 8107 8106 8113]
# atom 8096 is not at the interface.
# atom 8097 neighbors: [8084 8085 8093 7528 8104 7563 8094 8095 8096 8097 8098 8099 8100 7543]
# atom 8097 is not at the interface.
# atom 8098 neighbors: [8093 7860 8104 8094 8095 8096 8097 8098 8107 8099 8100 8101 7863]
# atom 8098 is not at the interface.
# atom 8099 neighbors: [8094 8097 8098 8099 8100 8101 8102 8103 7863 7543 7550]
# atom 8099 is not at the interface.
# atom 8100 neighbors: [7879 8097 8098 8099 8100 8101 8102 8103 7861 7863]
# atom 8100 is not at the interface.
# atom 8101 neighbors: [7879 8098 8099 8100 8101 8102 8103 7863 7550]
# atom 8101 is not at the interface.
# atom 8102 neighbors: [8099 8100 8101 8102 8103 7548 7549 7550 7552]
# atom 8102 is not at the interface.
# atom 8103 neighbors: [8099 8100 8101 8102 8103 7861 7863]
# atom 8103 is not at the interface.
# atom 8104 neighbors: [7851 8093 7528 8104 8105 8108 8094 8095 8096 8097 8098 8107 8106 8113
#  8109]
# atom 8104 is not at the interface.
# atom 8105 neighbors: [7851 8104 8105 8108 7836 8094 8095 8096 8107 8106 8113 8114 8109 8110]
# atom 8105 is not at the interface.
# atom 8106 neighbors: [8104 8105 8108 7836 8095 8096 8107 8106 8113 8114 8117 8109 8115 8116]
# atom 8106 is not at the interface.
# atom 8107 neighbors: [8104 8105 8108 8095 8096 8098 8107 8106 8113 8114 8109 8115 8116]
# atom 8107 is not at the interface.
# atom 8108 neighbors: [8104 8105 8108 8095 8107 8106 8113 8111 8109 8110]
# atom 8108 is not at the interface.
# atom 8109 neighbors: [8104 8105 8108 7836 8107 8106 8113 8111 8112 8109 8110 8116]
# atom 8109 is not at the interface.
# atom 8110 neighbors: [8105 8108 8111 8112 8109 8110]
# atom 8110 is not at the interface.
# atom 8111 neighbors: [7841 8108 7842 8111 8112 8109 8110]
# atom 8111 is not at the interface.
# atom 8112 neighbors: [7843 7841 7842 8111 8112 8109 8110]
# atom 8112 is not at the interface.
# atom 8113 neighbors: [8104 8105 8108 7836 8095 8096 8107 8106 8113 8114 8117 8118 8109 8115
#  8116]
# atom 8113 is not at the interface.
# atom 8114 neighbors: [8105 7836 8107 8106 8113 8114 8117 8118 8119 8115 8116]
# atom 8114 is not at the interface.
# atom 8115 neighbors: [8107 8106 8113 8114 8117 8118 8115 8116]
# atom 8115 is not at the interface.
# atom 8116 neighbors: [8107 8106 8113 8114 8117 8109 8115 8116]
# atom 8116 is not at the interface.
# atom 8117 neighbors: [8120 7836 8106 8113 8114 8117 8118 8119 8115 8116]
# atom 8117 is not at the interface.
# atom 8118 neighbors: [8120 8121 7836 8113 8114 8117 8118 8119 8115]
# atom 8118 is not at the interface.
# atom 8119 neighbors: [7830 7847 8120 8121 7835 7836 8114 8117 8118 8119]
# atom 8119 is not at the interface.
# atom 8120 neighbors: [7830 7847 8120 8121 8117 8118 8119]
# atom 8120 is not at the interface.
# atom 8121 neighbors: [7808 7829 7830 8120 8121 7809 8118 8119]
# atom 8121 is not at the interface.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from biotite.structure import CellList
from collections import defaultdict

cell = CellList(atom_array, cell_size=4.0)

bf_sum = defaultdict(float)

for i, coord in enumerate(atom_array.coord):
    neighbors = cell.get_atoms(coord, radius=4.0)
    neighbors = neighbors[neighbors != -1]

    # only count contacts to different chains
    mask = atom_array.chain_id[neighbors] != atom_array.chain_id[i]
    n_contact = np.sum(mask)

    cr = f"{atom_array.chain_id[i]}{atom_array.res_id[i]}"
    bf_sum[cr] += n_contact
    
print(bf_sum)

# write the residue b_factor score back to structure
bf_sum_atom = np.array([bf_sum[cr] for cr in chain_res])
atom_array.set_annotation("residue_b_factor", bf_sum_atom)
atom_array.set_annotation("chain_res", chain_res)

chain_res = atom_array.chain_res
b_factor = atom_array.residue_b_factor
df = pd.DataFrame({
    "chain_res": chain_res,
    "residue_b_factor": b_factor
})
df = df[df['residue_b_factor'] > 0]
df['res_num'] = df['chain_res'].str[1:].astype(int)
df = df.sort_values(by=['chain_res', 'res_num'])
plt.figure(figsize=(30, 6))
sns.barplot(data=df, x='chain_res', y='residue_b_factor', palette='viridis')
plt.xticks(rotation=90)
plt.xlabel('Residue (Chain + Resi)')
plt.ylabel('Sum of B-Factor Scores')
plt.title('Residue Interaction B-Factor Scores')
plt.tight_layout()
plt.show()
# Out:
# defaultdict(<class 'float'>, {'A1': np.float64(0.0), 'A2': np.float64(5.0), 'A3': np.float64(19.0), 'A4': np.float64(7.0), 'A5': np.float64(0.0), 'A6': np.float64(0.0), 'A7': np.float64(4.0), 'A8': np.float64(3.0), 'A9': np.float64(0.0), 'A10': np.float64(0.0), 'A11': np.float64(0.0), 'A12': np.float64(0.0), 'A13': np.float64(0.0), 'A14': np.float64(0.0), 'A15': np.float64(9.0), 'A16': np.float64(0.0), 'A17': np.float64(2.0), 'A18': np.float64(1.0), 'A19': np.float64(1.0), 'A20': np.float64(0.0), 'A21': np.float64(1.0), 'A22': np.float64(0.0), 'A23': np.float64(0.0), 'A24': np.float64(1.0), 'A25': np.float64(0.0), 'A26': np.float64(0.0), 'A27': np.float64(0.0), 'A28': np.float64(0.0), 'A29': np.float64(0.0), 'A30': np.float64(0.0), 'A31': np.float64(0.0), 'A32': np.float64(0.0), 'A33': np.float64(0.0), 'A34': np.float64(0.0), 'A35': np.float64(0.0), 'A36': np.float64(0.0), 'A37': np.float64(2.0), 'A38': np.float64(0.0), 'A39': np.float64(1.0), 'A40': np.float64(0.0), 'A41': np.float64(0.0), 'A42': np.float64(0.0), 'A43': np.float64(0.0), 'A44': np.float64(3.0), 'A45': np.float64(0.0), 'A46': np.float64(4.0), 'A47': np.float64(1.0), 'A48': np.float64(0.0), 'A49': np.float64(0.0), 'A50': np.float64(0.0), 'A51': np.float64(0.0), 'A52': np.float64(0.0), 'A53': np.float64(5.0), 'A54': np.float64(0.0), 'A55': np.float64(1.0), 'A56': np.float64(0.0), 'A57': np.float64(0.0), 'A58': np.float64(0.0), 'A59': np.float64(0.0), 'A60': np.float64(0.0), 'A61': np.float64(0.0), 'A62': np.float64(0.0), 'A63': np.float64(0.0), 'A64': np.float64(0.0), 'A65': np.float64(0.0), 'A66': np.float64(0.0), 'A67': np.float64(0.0), 'A68': np.float64(0.0), 'A69': np.float64(0.0), 'A70': np.float64(0.0), 'A71': np.float64(0.0), 'A72': np.float64(0.0), 'A73': np.float64(0.0), 'A74': np.float64(0.0), 'A75': np.float64(9.0), 'A76': np.float64(0.0), 'A77': np.float64(0.0), 'A78': np.float64(0.0), 'A79': np.float64(0.0), 'A80': np.float64(0.0), 'A81': np.float64(0.0), 'A82': np.float64(0.0), 'A83': np.float64(0.0), 'A84': np.float64(0.0), 'A85': np.float64(8.0), 'A86': np.float64(1.0), 'A87': np.float64(1.0), 'A88': np.float64(0.0), 'A89': np.float64(0.0), 'A90': np.float64(0.0), 'A91': np.float64(1.0), 'A92': np.float64(6.0), 'A93': np.float64(5.0), 'A94': np.float64(8.0), 'A95': np.float64(0.0), 'A96': np.float64(6.0), 'A97': np.float64(2.0), 'A98': np.float64(6.0), 'A99': np.float64(11.0), 'A100': np.float64(7.0), 'A101': np.float64(0.0), 'A102': np.float64(4.0), 'A103': np.float64(0.0), 'A104': np.float64(13.0), 'A105': np.float64(0.0), 'A106': np.float64(0.0), 'A107': np.float64(0.0), 'A108': np.float64(0.0), 'A109': np.float64(0.0), 'A110': np.float64(0.0), 'A111': np.float64(0.0), 'A112': np.float64(0.0), 'A113': np.float64(0.0), 'A114': np.float64(4.0), 'A115': np.float64(0.0), 'A116': np.float64(1.0), 'A117': np.float64(0.0), 'A118': np.float64(6.0), 'A119': np.float64(0.0), 'A120': np.float64(0.0), 'A121': np.float64(0.0), 'A122': np.float64(3.0), 'A123': np.float64(2.0), 'A124': np.float64(8.0), 'A125': np.float64(0.0), 'A126': np.float64(0.0), 'A127': np.float64(0.0), 'A128': np.float64(0.0), 'A129': np.float64(0.0), 'A130': np.float64(0.0), 'A131': np.float64(0.0), 'A132': np.float64(0.0), 'A133': np.float64(0.0), 'A134': np.float64(0.0), 'A135': np.float64(0.0), 'A136': np.float64(0.0), 'A137': np.float64(3.0), 'A138': np.float64(0.0), 'A139': np.float64(0.0), 'A140': np.float64(0.0), 'A141': np.float64(0.0), 'A142': np.float64(0.0), 'A143': np.float64(25.0), 'A144': np.float64(7.0), 'A145': np.float64(6.0), 'A146': np.float64(2.0), 'A147': np.float64(0.0), 'A148': np.float64(0.0), 'A149': np.float64(13.0), 'A150': np.float64(0.0), 'A151': np.float64(0.0), 'A152': np.float64(0.0), 'A153': np.float64(0.0), 'A154': np.float64(0.0), 'A155': np.float64(0.0), 'A156': np.float64(0.0), 'A157': np.float64(3.0), 'A158': np.float64(0.0), 'A159': np.float64(0.0), 'A160': np.float64(0.0), 'A161': np.float64(0.0), 'A162': np.float64(0.0), 'A163': np.float64(7.0) ...
# /tmp/ipykernel_301583/2941315759.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='chain_res', y='residue_b_factor', palette='viridis')

# %%
from biotite.structure import CellList

cell = CellList(atom_array, cell_size=2.0)

atom_C_mask = (atom_array.chain_id == 'A') & (atom_array.res_id == 1) & (atom_array.atom_name == 'C')
atom_N_mask = (atom_array.chain_id == 'A') & (atom_array.res_id == 2) & (atom_array.atom_name == 'N')

diff = atom_array[atom_C_mask].coord - atom_array[atom_N_mask].coord
dist = np.linalg.norm(diff)
print(f'C and N distance is {dist}')

has_clash = False
for i, coord in enumerate(atom_array.coord):
    neighbors = cell.get_atoms(coord, radius=2.0)
    neighbors = neighbors[neighbors != -1]

    # exclude itself
    neighbors = neighbors[neighbors != i]
    
    # exclude atoms from the same residue
    mask = atom_array.res_id[neighbors] != atom_array.res_id[i]
    neighbors = neighbors[mask]
    
    # exclude when atom name is C or N
    mask = ~np.isin(atom_array.atom_name[neighbors], ["C", "N"])
    neighbors = neighbors[mask]

    if len(neighbors) > 0:
        has_clash = True
        print(f"Atom {i} has clashes with atoms {neighbors}")
    else:
        continue
# Out:
# C and N distance is 1.3256494998931885
